# %% [markdown]
# # NHL Shot Data - Data Wrangling

# %%
from pathlib import Path
import pandas as pd
import numpy as np
import ast
import json
from statsmodels.distributions.empirical_distribution import ECDF
#from scipy import stats
from collections import Counter
import bz2
import _pickle as cPickle

# %% [markdown]
# ## Read Existing Frames

# %% [markdown]
# ### Obtain List of Games with Valid Frames
# The script `produce_game_frames.py` downloads and processes individual game reports for the seasons from 2010-11 onward. Initially, this notebook reads and combines valid game frames. Start by getting obtaining the list of all games.

# %%
SEASON_LIST = ['20102011', '20112012', '20122013', '20132014', '20142015', '20152016', '20162017', 
               '20172018', '20182019', '20192020']
def read_game_feed_links(season):
    '''
    Reads the local file containing live feed links for the current season, if it exists.

    Parameters
    ----------
    season : str
        The season for the schedule. Example: '20182019' for the 2018-19 season.

    Returns
    -------
    game_feed_links : list of str
        List of links to live feeds of games for the season, if the local file exists.
        Returns None if the file doesn't exist.
        An individual link has the form '/api/v1/game/2018020256/feed/live', where the substring '2018020256' represents 
        the NHL's game ID for the game. 
    '''
    current_dir = Path.cwd()
    relative_path = 'data/schedule_' + season + '.json'
    game_feed_link_path = current_dir.joinpath(relative_path) 
    
    with game_feed_link_path.open('r') as infile:
        game_feed_links = json.load(infile)
    return game_feed_links

def get_game_feed_links(seasons):
    '''
    Obtains game feed links for every season indicated in seasons.

    Parameters
    ----------
    seasons : str or list
        If a string, should be the season for the schedule. Example: '20182019' for the 2018-19 season.
        If a list, should be a list of strings in the format listed above. Example: ['20182019', '20152016']
        will obtain the information for the 2015-16 and 2018-19 seasons.

    Returns
    -------
    List of str
        List of links to live feeds of games for the season. An individual link has the form 
        '/api/v1/game/2018020256/feed/live', where the substring '2018020256' represents the NHL's game ID
        for the game. 

    '''
    return [ link 
            for season in seasons 
            for link in read_game_feed_links(season)]

# %%
game_links = get_game_feed_links(SEASON_LIST)

# %%
len(game_links)
# Out:
# 12646

# %% [markdown]
# A handful of these links have missing or broken play-by-play reports. The file `bad_links.json` has been produced to contain a list of these bad games. Since no data can be obtained from these games, they will be ignored. Approximately 0.68% of games are affected.

# %%
def get_missing_links(live_feed_links):
    current_dir = Path.cwd()
    relative_path = 'data/bad_links.json'
    bad_link_path = current_dir.joinpath(relative_path)   
    with bad_link_path.open('r') as infile:
        bad_links = json.load(infile)
    return bad_links

# %%
missing_links = get_missing_links(game_links)

# %%
len(missing_links)
# Out:
# 85

# %%
broken_links = ['/api/v1/game/2010020124/feed/live', '/api/v1/game/2013020971/feed/live']
bad_links = missing_links + broken_links

# %% [markdown]
# ### Read Data Frames for Valid Games
# Each game not marked as invalid has a data frame which tracks all shots taken during the game. Read those in now and combine all into a single frame.

# %%
def read_game_frame(live_feed_link):
    current_dir = Path.cwd()
    game_id = live_feed_link[13:23]
    
    relative_path = 'data/games/combined_' + game_id + '.pkl'
    frame_path = current_dir.joinpath(relative_path)
    
    game_frame = pd.read_pickle(str(frame_path))
    return game_frame

# %%
combined_frame_list = [read_game_frame(link) for link in game_links if link not in bad_links]
shot_frame = pd.concat(combined_frame_list)
shot_frame.reset_index(drop=True, inplace=True)

# %% [markdown]
# ## Clean Shot Data
# Now that the data has been read, clean it.

# %% [markdown]
# The field `game_id_htmlreport` was included in the individual game summaries for error-checking purposes. It is not needed since it should be redundant with `game_id_livefeed`.

# %%
shot_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1428368 entries, 0 to 1428367
# Data columns (total 37 columns):
#  #   Column              Non-Null Count    Dtype
# ---  ------              --------------    -----
#  0   game_id_livefeed    1428356 non-null  object
#  1   season              1428356 non-null  object
#  2   type                1428356 non-null  object
#  3   game_time           1428356 non-null  object
#  4   away_code           1428356 non-null  object
#  5   home_code           1428356 non-null  object
#  6   venue               1428356 non-null  object
#  7   period              1428368 non-null  int64
#  8   period_ord          1428356 non-null  object
#  9   period_type         1428356 non-null  object
#  10  time_elapsed        1428368 non-null  object
#  11  cum_time_elapsed    1428356 non-null  float64
#  12  event               1428368 non-null  object
#  13  event_team_code     1428356 non-null  object
#  14  event_team_is_home  1428368 non-null  bool
#  15  event_coord_x       1428334 non-null  float64
#  16  event_coord_y       1428332 non-null  float64
#  17  secondary_type      769702 non-null   object
#  18  is_rebound          1428356 non-null  object
#  19  strength            1428368 non-null  object
#  20  time_remaining      1428368 non-null  object
#  21  pos_a               1428364 non-null  object
#  22  pos_h               1428364 non-null  object
#  23  game_id_htmlreport  1428368 non-null  object
#  24  seconds_remaining   1428368 non-null  float64
#  25  fwd_def_a           1428364 non-null  object
#  26  fwd_def_h           1428364 non-null  object
#  27  skaters_a           1428364 non-null  object
#  28  skaters_h           1428364 non-null  object
#  29  goalie_pulled_a     1428364 non-null  object
#  30  goalie_pulled_h     1428364 non-null  object
#  31  shot_dist           1066195 non-null  float64
#  32  event_zone          1428350 non-null  object
#  33  miss_type           1359133 non-null  object
#  34  shot_type           1428265 non-null  object
#  35  calc_dist           1428328 non-null  float64
#  36  dist_difference     1066161 non-null  float64
# dtypes: bool(1), float64(7), int64(1), object(28)
# memory usage: 393.7+ MB

# %%
# game_id_htmlreport is redundant and can be removed.
shot_frame.drop('game_id_htmlreport', axis=1, inplace=True)

# %% [markdown]
# There are a handful of shots which seem to appear in the html play-by-play data, but not in the game live feed. This can occur when postgame evaluation of the play-by-play makes different determinations as to whether events were shots. These will be ignored as well.

# %%
shot_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1428368 entries, 0 to 1428367
# Data columns (total 36 columns):
#  #   Column              Non-Null Count    Dtype
# ---  ------              --------------    -----
#  0   game_id_livefeed    1428356 non-null  object
#  1   season              1428356 non-null  object
#  2   type                1428356 non-null  object
#  3   game_time           1428356 non-null  object
#  4   away_code           1428356 non-null  object
#  5   home_code           1428356 non-null  object
#  6   venue               1428356 non-null  object
#  7   period              1428368 non-null  int64
#  8   period_ord          1428356 non-null  object
#  9   period_type         1428356 non-null  object
#  10  time_elapsed        1428368 non-null  object
#  11  cum_time_elapsed    1428356 non-null  float64
#  12  event               1428368 non-null  object
#  13  event_team_code     1428356 non-null  object
#  14  event_team_is_home  1428368 non-null  bool
#  15  event_coord_x       1428334 non-null  float64
#  16  event_coord_y       1428332 non-null  float64
#  17  secondary_type      769702 non-null   object
#  18  is_rebound          1428356 non-null  object
#  19  strength            1428368 non-null  object
#  20  time_remaining      1428368 non-null  object
#  21  pos_a               1428364 non-null  object
#  22  pos_h               1428364 non-null  object
#  23  seconds_remaining   1428368 non-null  float64
#  24  fwd_def_a           1428364 non-null  object
#  25  fwd_def_h           1428364 non-null  object
#  26  skaters_a           1428364 non-null  object
#  27  skaters_h           1428364 non-null  object
#  28  goalie_pulled_a     1428364 non-null  object
#  29  goalie_pulled_h     1428364 non-null  object
#  30  shot_dist           1066195 non-null  float64
#  31  event_zone          1428350 non-null  object
#  32  miss_type           1359133 non-null  object
#  33  shot_type           1428265 non-null  object
#  34  calc_dist           1428328 non-null  float64
#  35  dist_difference     1066161 non-null  float64
# dtypes: bool(1), float64(7), int64(1), object(27)
# memory usage: 382.8+ MB

# %%
pd.set_option('display.max_columns', None)

# %%
shot_frame.head()
# Out:
#   game_id_livefeed    season type             game_time away_code home_code  \
# 0       2010020003  20102011    R  2010-10-07T16:00:00Z       CAR       MIN
# 1       2010020003  20102011    R  2010-10-07T16:00:00Z       CAR       MIN
# 2       2010020003  20102011    R  2010-10-07T16:00:00Z       CAR       MIN
# 3       2010020003  20102011    R  2010-10-07T16:00:00Z       CAR       MIN
# 4       2010020003  20102011    R  2010-10-07T16:00:00Z       CAR       MIN
#
#              venue  period period_ord period_type time_elapsed  \
# 0  Hartwall Areena       1        1st     REGULAR        01:05
# 1  Hartwall Areena       1        1st     REGULAR        01:16
# 2  Hartwall Areena       1        1st     REGULAR        01:37
# 3  Hartwall Areena       1        1st     REGULAR        03:33
# 4  Hartwall Areena       1        1st     REGULAR        03:49
#
#    cum_time_elapsed  event event_team_code  event_team_is_home  event_coord_x  \
# 0              65.0   SHOT             CAR               False           56.0
# 1              76.0   MISS             CAR               False           35.0
# 2              97.0   MISS             MIN                True           87.0
# 3             213.0   GOAL             MIN                True           78.0
# 4             229.0  BLOCK             MIN                True           77.0
#
#    event_coord_y secondary_type is_rebound strength time_remaining  \
# 0          -15.0      Snap Shot      False       EV          18:55
# 1           33.0           None      False       EV          18:44
# 2           -6.0           None      False       EV          18:23
# 3            3.0     Wrist Shot      False       EV          16:27
# 4           13.0           None      False       EV          16:11
#
#                                       pos_a  \
# 0  {'C': 1, 'R': 1, 'L': 1, 'D': 2, 'G': 1}
# 1  {'C': 1, 'R': 1, 'L': 1, 'D': 2, 'G': 1}
# 2  {'C': 1, 'R': 1, 'L': 1, 'D': 2, 'G': 1}
# 3  {'C': 1, 'R': 1, 'L': 1, 'D': 2, 'G': 1}
# 4  {'C': 1, 'R': 1, 'L': 1, 'D': 2, 'G': 1}
#
#                                       pos_h  seconds_remaining  \
# 0          {'C': 1, 'R': 2, 'D': 2, 'G': 1}             1135.0
# 1          {'C': 1, 'R': 2, 'D': 2, 'G': 1}             1124.0
# 2  {'C': 1, 'R': 1, 'L': 1, 'D': 2, 'G': 1}             1103.0
# 3          {'C': 2, 'L': 1, 'D': 2, 'G': 1}              987.0
# 4  {'C': 1, 'R': 1, 'L': 1, 'D': 2, 'G': 1}              971.0
#
#                          fwd_def_a                        fwd_def_h  \
# 0  {'FWD': 3, 'DEF': 2, 'GOAL': 1}  {'FWD': 3, 'DEF': 2, 'GOAL': 1}
# 1  {'FWD': 3, 'DEF': 2, 'GOAL': 1}  {'FWD': 3, 'DEF': 2, 'GOAL': 1}
# 2  {'FWD': 3, 'DEF': 2, 'GOAL': 1}  {'FWD': 3, 'DEF': 2, 'GOAL': 1}
# 3  {'FWD': 3, 'DEF': 2, 'GOAL': 1}  {'FWD': 3, 'DEF': 2, 'GOAL': 1}
# 4  {'FWD': 3, 'DEF': 2, 'GOAL': 1}  {'FWD': 3, 'DEF': 2, 'GOAL': 1}
#
#                 skaters_a               skaters_h goalie_pulled_a  \
# 0  {'SKTR': 5, 'GOAL': 1}  {'SKTR': 5, 'GOAL': 1}           False
# 1  {'SKTR': 5, 'GOAL': 1}  {'SKTR': 5, 'GOAL': 1}           False
# 2  {'SKTR': 5, 'GOAL': 1}  {'SKTR': 5, 'GOAL': 1}           False
# 3  {'SKTR': 5, 'GOAL': 1}  {'SKTR': 5, 'GOAL': 1}           False
# 4  {'SKTR': 5, 'GOAL': 1}  {'SKTR': 5, 'GOAL': 1}           False
#
#   goalie_pulled_h  shot_dist event_zone    miss_type shot_type  calc_dist  \
# 0           False       37.0  Off. Zone         Save      Snap  36.249138
# 1           False       64.0  Off. Zone  Wide of Net     Wrist  63.285069
# 2           False        6.0  Off. Zone  Wide of Net     Wrist   6.324555
# 3           False       12.0  Off. Zone         None     Wrist  11.401754
# 4           False        NaN  Off. Zone        Block      Snap  17.691806
#
#    dist_difference
# 0         0.750862
# 1         0.714931
# 2         0.324555
# 3         0.598246
# 4              NaN

# %%
shot_frame[shot_frame.game_id_livefeed.isna()]
# Out:
#         game_id_livefeed season type game_time away_code home_code venue  \
# 592608               NaN    NaN  NaN       NaN       NaN       NaN   NaN
# 621845               NaN    NaN  NaN       NaN       NaN       NaN   NaN
# 652166               NaN    NaN  NaN       NaN       NaN       NaN   NaN
# 652167               NaN    NaN  NaN       NaN       NaN       NaN   NaN
# 652168               NaN    NaN  NaN       NaN       NaN       NaN   NaN
# 841902               NaN    NaN  NaN       NaN       NaN       NaN   NaN
# 1377738              NaN    NaN  NaN       NaN       NaN       NaN   NaN
# 1377739              NaN    NaN  NaN       NaN       NaN       NaN   NaN
# 1377740              NaN    NaN  NaN       NaN       NaN       NaN   NaN
# 1377741              NaN    NaN  NaN       NaN       NaN       NaN   NaN
# 1384659              NaN    NaN  NaN       NaN       NaN       NaN   NaN
# 1412256              NaN    NaN  NaN       NaN       NaN       NaN   NaN
#
#          period period_ord period_type time_elapsed  cum_time_elapsed  event  \
# 592608        3        NaN         NaN        16:02               NaN  BLOCK
# 621845        3        NaN         NaN        19:41               NaN   SHOT
# 652166        3        NaN         NaN        18:44               NaN   SHOT
# 652167        3        NaN         NaN        18:45               NaN   SHOT
# 652168        3        NaN         NaN        18:47               NaN   SHOT
# 841902        3        NaN         NaN        06:00               NaN   MISS
# 1377738       1        NaN         NaN        05:01               NaN  BLOCK
# 1377739       1        NaN         NaN        11:06               NaN   SHOT
# 1377740       1        NaN         NaN        15:02               NaN   SHOT
# 1377741       2        NaN         NaN        14:10               NaN   SHOT
# 1384659       3        NaN         NaN        18:32               NaN   SHOT
# 1412256       3        NaN         NaN        18:13               NaN   SHOT
#
#         event_team_code  event_team_is_home  event_coord_x  event_coord_y  \
# 592608              NaN               False            NaN            NaN
# 621845              NaN                True            NaN            NaN
# 652166              NaN                True            NaN            NaN
# 652167              NaN                True            NaN            NaN
# 652168              NaN                True            NaN            NaN
# 841902              NaN                True            NaN            NaN
# 1377738             NaN               False            NaN            NaN
# 1377739             NaN                True            NaN            NaN
# 1377740             NaN                True            NaN            NaN
# 1377741             NaN                True            NaN            NaN
# 1384659             NaN                True            NaN            NaN
# 1412256             NaN                True            NaN            NaN
#
#         secondary_type is_rebound strength time_remaining  \
# 592608             NaN        NaN       EV          03:58
# 621845             NaN        NaN       PP          00:19
# 652166             NaN        NaN       PP          01:16
# 652167             NaN        NaN       PP          01:15
# 652168             NaN        NaN       PP          01:13
# 841902             NaN        NaN       EV          14:00
# 1377738            NaN        NaN       EV          14:59
# 1377739            NaN        NaN       SH          08:54
# 1377740            NaN        NaN       PP          04:58
# 1377741            NaN        NaN       EV          05:50
# 1384659            NaN        NaN       EV          01:28
# 1412256            NaN        NaN       EV          01:47
#
#                                             pos_a  \
# 592608           {'C': 2, 'L': 1, 'D': 2, 'G': 1}
# 621845                   {'C': 2, 'D': 3, 'G': 1}
# 652166                   {'L': 2, 'D': 2, 'G': 1}
# 652167                   {'L': 2, 'D': 2, 'G': 1}
# 652168                   {'L': 2, 'D': 2, 'G': 1}
# 841902   {'C': 1, 'R': 1, 'L': 1, 'D': 2, 'G': 1}
# 1377738          {'C': 2, 'L': 1, 'D': 2, 'G': 1}
# 1377739  {'C': 1, 'R': 1, 'L': 2, 'D': 1, 'G': 1}
# 1377740          {'C': 2, 'L': 2, 'D': 1, 'G': 1}
# 1377741          {'C': 1, 'R': 2, 'D': 2, 'G': 1}
# 1384659                  {'C': 3, 'D': 2, 'G': 1}
# 1412256          {'C': 2, 'L': 1, 'D': 2, 'G': 1}
#
#                                             pos_h  seconds_remaining  \
# 592608           {'C': 2, 'R': 1, 'D': 2, 'G': 1}              238.0
# 621845           {'C': 1, 'L': 1, 'D': 2, 'G': 1}               19.0
# 652166           {'C': 2, 'R': 1, 'L': 1, 'D': 2}               76.0
# 652167           {'C': 2, 'R': 1, 'L': 1, 'D': 2}               75.0
# 652168           {'C': 2, 'R': 1, 'L': 1, 'D': 2}               73.0
# 841902   {'C': 1, 'R': 1, 'L': 1, 'D': 2, 'G': 1}              840.0
# 1377738          {'C': 1, 'R': 2, 'D': 2, 'G': 1}              899.0
# 1377739          {'C': 1, 'R': 1, 'D': 2, 'G': 1}              534.0
# 1377740          {'C': 1, 'L': 1, 'D': 2, 'G': 1}              298.0
# 1377741  {'C': 1, 'R': 1, 'L': 1, 'D': 2, 'G': 1}              350.0
# 1384659                  {'C': 4, 'R': 1, 'D': 1}               88.0
# 1412256          {'C': 2, 'R': 1, 'D': 2, 'G': 1}              107.0
#
#                                fwd_def_a                        fwd_def_h  \
# 592608   {'FWD': 3, 'DEF': 2, 'GOAL': 1}  {'FWD': 3, 'DEF': 2, 'GOAL': 1}
# 621845   {'FWD': 2, 'DEF': 3, 'GOAL': 1}  {'FWD': 2, 'DEF': 2, 'GOAL': 1}
# 652166   {'FWD': 2, 'DEF': 2, 'GOAL': 1}             {'FWD': 4, 'DEF': 2}
# 652167   {'FWD': 2, 'DEF': 2, 'GOAL': 1}             {'FWD': 4, 'DEF': 2}
# 652168   {'FWD': 2, 'DEF': 2, 'GOAL': 1}             {'FWD': 4, 'DEF': 2}
# 841902   {'FWD': 3, 'DEF': 2, 'GOAL': 1}  {'FWD': 3, 'DEF': 2, 'GOAL': 1}
# 1377738  {'FWD': 3, 'DEF': 2, 'GOAL': 1}  {'FWD': 3, 'DEF': 2, 'GOAL': 1}
# 1377739  {'FWD': 4, 'DEF': 1, 'GOAL': 1}  {'FWD': 2, 'DEF': 2, 'GOAL': 1}
# 1377740  {'FWD': 4, 'DEF': 1, 'GOAL': 1}  {'FWD': 2, 'DEF': 2, 'GOAL': 1}
# 1377741  {'FWD': 3, 'DEF': 2, 'GOAL': 1}  {'FWD': 3, 'DEF': 2, 'GOAL': 1}
# 1384659  {'FWD': 3, 'DEF': 2, 'GOAL': 1}             {'FWD': 5, 'DEF': 1}
# 1412256  {'FWD': 3, 'DEF': 2, 'GOAL': 1}  {'FWD': 3, 'DEF': 2, 'GOAL': 1}
#
#                       skaters_a               skaters_h goalie_pulled_a  \
# 592608   {'SKTR': 5, 'GOAL': 1}  {'SKTR': 5, 'GOAL': 1}           False
# 621845   {'SKTR': 5, 'GOAL': 1}  {'SKTR': 4, 'GOAL': 1}           False
# 652166   {'SKTR': 4, 'GOAL': 1}             {'SKTR': 6}           False
# 652167   {'SKTR': 4, 'GOAL': 1}             {'SKTR': 6}           False
# 652168   {'SKTR': 4, 'GOAL': 1}             {'SKTR': 6}           False
# 841902   {'SKTR': 5, 'GOAL': 1}  {'SKTR': 5, 'GOAL': 1}           False
# 1377738  {'SKTR': 5, 'GOAL': 1}  {'SKTR': 5, 'GOAL': 1}           False
# 1377739  {'SKTR': 5, 'GOAL': 1}  {'SKTR': 4, 'GOAL': 1}           False
# 1377740  {'SKTR': 5, 'GOAL': 1}  {'SKTR': 4, 'GOAL': 1}           False
# 1377741  {'SKTR': 5, 'GOAL': 1}  {'SKTR': 5, 'GOAL': 1}           False
# 1384659  {'SKTR': 5, 'GOAL': 1}             {'SKTR': 6}           False
# 1412256  {'SKTR': 5, 'GOAL': 1}  {'SKTR': 5, 'GOAL': 1}           False
#
#         goalie_pulled_h  shot_dist event_zone    miss_type shot_type  \
# 592608            False        NaN  Off. Zone        Block     Wrist
# 621845            False       36.0  Off. Zone         Save     Wrist
# 652166             True       23.0  Off. Zone         Save     Wrist
# 652167             True       52.0  Off. Zone         Save     Wrist
# 652168             True       18.0  Off. Zone         Save     Wrist
# 841902            False       40.0  Off. Zone  Wide of Net     Wrist
# 1377738           False        NaN  Off. Zone        Block     Wrist
# 1377739           False       11.0  Off. Zone         Save  Backhand
# 1377740           False       21.0  Off. Zone         Save     Wrist
# 1377741           False       58.0  Off. Zone         Save     Wrist
# 1384659            True       47.0  Off. Zone         Save      Snap
# 1412256           False       82.0  Neu. Zone         Save     Wrist
#
#          calc_dist  dist_difference
# 592608         NaN              NaN
# 621845         NaN              NaN
# 652166         NaN              NaN
# 652167         NaN              NaN
# 652168         NaN              NaN
# 841902         NaN              NaN
# 1377738        NaN              NaN
# 1377739        NaN              NaN
# 1377740        NaN              NaN
# 1377741        NaN              NaN
# 1384659        NaN              NaN
# 1412256        NaN              NaN

# %%
shot_frame.dropna(subset=['game_id_livefeed'], inplace=True)

# %% [markdown]
# A few shots are missing coordinates. These will also be ignored.

# %%
shot_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1428356 entries, 0 to 1428367
# Data columns (total 36 columns):
#  #   Column              Non-Null Count    Dtype
# ---  ------              --------------    -----
#  0   game_id_livefeed    1428356 non-null  object
#  1   season              1428356 non-null  object
#  2   type                1428356 non-null  object
#  3   game_time           1428356 non-null  object
#  4   away_code           1428356 non-null  object
#  5   home_code           1428356 non-null  object
#  6   venue               1428356 non-null  object
#  7   period              1428356 non-null  int64
#  8   period_ord          1428356 non-null  object
#  9   period_type         1428356 non-null  object
#  10  time_elapsed        1428356 non-null  object
#  11  cum_time_elapsed    1428356 non-null  float64
#  12  event               1428356 non-null  object
#  13  event_team_code     1428356 non-null  object
#  14  event_team_is_home  1428356 non-null  bool
#  15  event_coord_x       1428334 non-null  float64
#  16  event_coord_y       1428332 non-null  float64
#  17  secondary_type      769702 non-null   object
#  18  is_rebound          1428356 non-null  object
#  19  strength            1428356 non-null  object
#  20  time_remaining      1428356 non-null  object
#  21  pos_a               1428352 non-null  object
#  22  pos_h               1428352 non-null  object
#  23  seconds_remaining   1428356 non-null  float64
#  24  fwd_def_a           1428352 non-null  object
#  25  fwd_def_h           1428352 non-null  object
#  26  skaters_a           1428352 non-null  object
#  27  skaters_h           1428352 non-null  object
#  28  goalie_pulled_a     1428352 non-null  object
#  29  goalie_pulled_h     1428352 non-null  object
#  30  shot_dist           1066185 non-null  float64
#  31  event_zone          1428338 non-null  object
#  32  miss_type           1359121 non-null  object
#  33  shot_type           1428253 non-null  object
#  34  calc_dist           1428328 non-null  float64
#  35  dist_difference     1066161 non-null  float64
# dtypes: bool(1), float64(7), int64(1), object(27)
# memory usage: 393.7+ MB

# %%
shot_frame[shot_frame['event_coord_x'].isna() | shot_frame['event_coord_y'].isna()]
# Out:
#         game_id_livefeed    season type             game_time away_code  \
# 25893         2010020237  20102011    R  2010-11-14T00:00:00Z       FLA
# 95315         2010020863  20102011    R  2011-02-18T00:00:00Z       BOS
# 149485        2011020031  20112012    R  2011-10-10T22:00:00Z       PHX
# 263572        2011021075  20112012    R  2012-03-18T02:30:00Z       DET
# 338102        2012020446  20122013    R  2013-03-21T23:00:00Z       NJD
# 341983        2012020482  20122013    R  2013-03-26T23:00:00Z       WPG
# 364236        2012020684  20122013    R  2013-04-23T23:30:00Z       BOS
# 394817        2013020143  20132014    R  2013-10-24T23:30:00Z       CHI
# 402275        2013020212  20132014    R  2013-11-03T18:00:00Z       DAL
# 488918        2013020999  20132014    R  2014-03-14T23:30:00Z       NJD
# 518080        2013030154  20132014    P  2014-04-25T01:30:00Z       COL
# 536809        2014020103  20142015    R  2014-10-25T01:00:00Z       VAN
# 584485        2014020527  20142015    R  2014-12-28T22:00:00Z       TOR
# 585703        2014020538  20142015    R  2014-12-30T01:30:00Z       NYR
# 714427        2015020367  20152016    R  2015-12-02T03:30:00Z       VAN
# 870152        2016020428  20162017    R  2016-12-12T02:30:00Z       WPG
# 904834        2016020738  20162017    R  2017-01-27T01:30:00Z       BUF
# 912105        2016020801  20162017    R  2017-02-09T01:00:00Z       CHI
# 934625        2016020999  20162017    R  2017-03-11T02:00:00Z       PIT
# 977077        2017020047  20172018    R  2017-10-11T23:30:00Z       PIT
# 1003452       2017020273  20172018    R  2017-11-15T02:00:00Z       VGK
# 1016715       2017020387  20172018    R  2017-12-01T02:00:00Z       TOR
# 1138159       2018020055  20182019    R  2018-10-12T00:00:00Z       WPG
# 1198111       2018020573  20182019    R  2018-12-28T01:00:00Z       DAL
# 1243158       2018020963  20182019    R  2019-02-26T00:00:00Z       MTL
# 1246819       2018020993  20182019    R  2019-03-02T00:00:00Z       WSH
# 1260658       2018021114  20182019    R  2019-03-17T23:00:00Z       VAN
# 1262047       2018021122  20182019    R  2019-03-19T23:30:00Z       WSH
#
#         home_code                      venue  period period_ord period_type  \
# 25893         PHI         Wells Fargo Center       1        1st     REGULAR
# 95315         NYI            Nassau Coliseum       3        3rd     REGULAR
# 149485        DAL   American Airlines Center       3        3rd     REGULAR
# 263572        SJS    HP Pavilion at San Jose       2        2nd     REGULAR
# 338102        CAR                  PNC Arena       1        1st     REGULAR
# 341983        CAR                  PNC Arena       3        3rd     REGULAR
# 364236        PHI         Wells Fargo Center       2        2nd     REGULAR
# 394817        TBL      Tampa Bay Times Forum       3        3rd     REGULAR
# 402275        OTT       Canadian Tire Centre       3        3rd     REGULAR
# 488918        FLA                BB&T Center       1        1st     REGULAR
# 518080        MIN         Xcel Energy Center       3        3rd     REGULAR
# 536809        COL               Pepsi Center       3        3rd     REGULAR
# 584485        FLA                BB&T Center       3        3rd     REGULAR
# 585703        DAL   American Airlines Center       2        2nd     REGULAR
# 714427        LAK             STAPLES Center       1        1st     REGULAR
# 870152        EDM               Rogers Place       3        3rd     REGULAR
# 904834        DAL   American Airlines Center       2        2nd     REGULAR
# 912105        MIN         Xcel Energy Center       4         OT    OVERTIME
# 934625        EDM               Rogers Place       1        1st     REGULAR
# 977077        WSH          Capital One Arena       3        3rd     REGULAR
# 1003452       EDM               Rogers Place       3        3rd     REGULAR
# 1016715       EDM               Rogers Place       3        3rd     REGULAR
# 1138159       NSH          Bridgestone Arena       2        2nd     REGULAR
# 1198111       NSH          Bridgestone Arena       2        2nd     REGULAR
# 1243158       NJD          Prudential Center       1        1st     REGULAR
# 1246819       NYI  NYCB Live/Nassau Coliseum       3        3rd     REGULAR
# 1260658       DAL   American Airlines Center       1        1st     REGULAR
# 1262047       NJD          Prudential Center       1        1st     REGULAR
#
#         time_elapsed  cum_time_elapsed  event event_team_code  \
# 25893          05:52             352.0  BLOCK             FLA
# 95315          19:10            3550.0  BLOCK             NYI
# 149485         05:53            2753.0   SHOT             PHX
# 263572         06:50            1610.0   SHOT             DET
# 338102         03:54             234.0   GOAL             NJD
# 341983         12:37            3157.0   GOAL             WPG
# 364236         11:31            1891.0   GOAL             PHI
# 394817         18:11            3491.0   GOAL             CHI
# 402275         03:11            2591.0   GOAL             DAL
# 488918         17:10            1030.0   MISS             FLA
# 518080         14:37            3277.0   SHOT             MIN
# 536809         19:16            3556.0   GOAL             COL
# 584485         10:03            3003.0   SHOT             TOR
# 585703         10:10            1810.0   SHOT             DAL
# 714427         04:15             255.0   SHOT             VAN
# 870152         11:21            3081.0   GOAL             EDM
# 904834         15:24            2124.0   GOAL             DAL
# 912105         03:05            3785.0   SHOT             CHI
# 934625         17:25            1045.0   GOAL             PIT
# 977077         18:40            3520.0   MISS             WSH
# 1003452        00:57            2457.0   GOAL             EDM
# 1016715        18:55            3535.0   GOAL             TOR
# 1138159        16:38            2198.0  BLOCK             NSH
# 1198111        14:50            2090.0  BLOCK             DAL
# 1243158        14:31             871.0   SHOT             MTL
# 1246819        18:32            3512.0   GOAL             WSH
# 1260658        10:53             653.0   GOAL             VAN
# 1262047        02:52             172.0   GOAL             WSH
#
#          event_team_is_home  event_coord_x  event_coord_y secondary_type  \
# 25893                 False          -65.0            NaN           None
# 95315                  True           46.0            NaN           None
# 149485                False            NaN            NaN      Slap Shot
# 263572                False           31.0            NaN     Wrist Shot
# 338102                False            NaN            NaN           None
# 341983                False            NaN            NaN           None
# 364236                 True            NaN            NaN           None
# 394817                False            NaN            NaN           None
# 402275                False            NaN            NaN      Deflected
# 488918                 True            NaN          -13.0           None
# 518080                 True            NaN            NaN      Slap Shot
# 536809                 True            NaN            3.0         Tip-In
# 584485                False            NaN            NaN       Backhand
# 585703                 True            NaN            NaN     Wrist Shot
# 714427                False          -26.0            NaN      Snap Shot
# 870152                 True            NaN            NaN           None
# 904834                 True            NaN            NaN           None
# 912105                False            NaN            NaN      Slap Shot
# 934625                False            NaN            NaN           None
# 977077                 True            NaN            NaN           None
# 1003452                True            NaN            NaN     Wrist Shot
# 1016715               False            NaN            NaN     Wrist Shot
# 1138159                True            NaN            NaN           None
# 1198111               False          -19.0            NaN           None
# 1243158               False           66.0            NaN      Snap Shot
# 1246819               False            NaN            NaN           None
# 1260658               False            NaN          -17.0      Snap Shot
# 1262047               False            NaN          -15.0     Wrist Shot
#
#         is_rebound strength time_remaining  \
# 25893        False       EV          14:08
# 95315        False       EV          00:50
# 149485       False       PP          14:07
# 263572       False       EV          13:10
# 338102       False       PP          16:06
# 341983       False       EV          07:23
# 364236       False       EV          08:29
# 394817       False       EV          01:49
# 402275       False       EV          16:49
# 488918       False       EV          02:50
# 518080       False       PP          05:23
# 536809       False       EV          00:44
# 584485       False       EV          09:57
# 585703       False       PP          09:50
# 714427       False       EV          15:45
# 870152        True       EV          08:39
# 904834        True       EV          04:36
# 912105       False       PP          01:55
# 934625        True       EV          02:35
# 977077       False       EV          01:20
# 1003452      False       PP          19:03
# 1016715       True       EV          01:05
# 1138159      False       PP          03:22
# 1198111      False       EV          05:10
# 1243158      False       EV          05:29
# 1246819      False       EV          01:28
# 1260658      False       EV          09:07
# 1262047      False       EV          17:08
#
#                                             pos_a  \
# 25893            {'C': 1, 'L': 2, 'D': 2, 'G': 1}
# 95315    {'C': 1, 'R': 1, 'L': 1, 'D': 2, 'G': 1}
# 149485   {'C': 1, 'R': 2, 'L': 1, 'D': 1, 'G': 1}
# 263572           {'C': 1, 'L': 2, 'D': 2, 'G': 1}
# 338102   {'C': 1, 'R': 1, 'L': 2, 'D': 1, 'G': 1}
# 341983   {'C': 1, 'R': 1, 'L': 1, 'D': 2, 'G': 1}
# 364236           {'C': 2, 'R': 1, 'D': 2, 'G': 1}
# 394817           {'C': 1, 'R': 2, 'D': 2, 'G': 1}
# 402275           {'C': 2, 'L': 1, 'D': 2, 'G': 1}
# 488918   {'C': 1, 'R': 1, 'L': 1, 'D': 2, 'G': 1}
# 518080           {'C': 1, 'R': 1, 'D': 2, 'G': 1}
# 536809           {'C': 1, 'R': 2, 'D': 2, 'G': 1}
# 584485           {'C': 2, 'L': 1, 'D': 2, 'G': 1}
# 585703           {'C': 1, 'L': 1, 'D': 2, 'G': 1}
# 714427   {'C': 1, 'R': 1, 'L': 1, 'D': 2, 'G': 1}
# 870152           {'C': 2, 'R': 1, 'D': 2, 'G': 1}
# 904834   {'C': 1, 'R': 1, 'L': 1, 'D': 2, 'G': 1}
# 912105           {'C': 2, 'R': 1, 'D': 1, 'G': 1}
# 934625           {'C': 2, 'L': 1, 'D': 2, 'G': 1}
# 977077   {'C': 1, 'R': 1, 'L': 1, 'D': 2, 'G': 1}
# 1003452          {'C': 1, 'R': 1, 'D': 2, 'G': 1}
# 1016715          {'C': 2, 'R': 1, 'D': 2, 'G': 1}
# 1138159                  {'C': 2, 'D': 2, 'G': 1}
# 1198111                  {'C': 3, 'D': 2, 'G': 1}
# 1243158          {'C': 2, 'L': 1, 'D': 2, 'G': 1}
# 1246819          {'C': 2, 'R': 1, 'D': 2, 'G': 1}
# 1260658          {'C': 2, 'R': 1, 'D': 2, 'G': 1}
# 1262047  {'C': 1, 'R': 1, 'L': 1, 'D': 2, 'G': 1}
#
#                                             pos_h  seconds_remaining  \
# 25893            {'C': 1, 'L': 2, 'D': 2, 'G': 1}              848.0
# 95315                    {'C': 3, 'D': 2, 'G': 1}               50.0
# 149485           {'C': 1, 'R': 1, 'D': 2, 'G': 1}              847.0
# 263572                   {'C': 3, 'D': 2, 'G': 1}              790.0
# 338102           {'C': 1, 'R': 1, 'D': 2, 'G': 1}              966.0
# 341983           {'C': 2, 'R': 1, 'D': 2, 'G': 1}              443.0
# 364236   {'C': 1, 'R': 1, 'L': 1, 'D': 2, 'G': 1}              509.0
# 394817           {'C': 2, 'R': 1, 'D': 2, 'G': 1}              109.0
# 402275           {'C': 2, 'L': 1, 'D': 2, 'G': 1}             1009.0
# 488918           {'C': 2, 'R': 1, 'D': 2, 'G': 1}              170.0
# 518080   {'C': 1, 'R': 1, 'L': 1, 'D': 2, 'G': 1}              323.0
# 536809   {'C': 1, 'R': 1, 'L': 1, 'D': 2, 'G': 1}               44.0
# 584485                   {'C': 3, 'D': 2, 'G': 1}              597.0
# 585703           {'C': 3, 'L': 1, 'D': 1, 'G': 1}              590.0
# 714427   {'C': 1, 'R': 1, 'L': 1, 'D': 2, 'G': 1}              945.0
# 870152           {'C': 2, 'L': 1, 'D': 2, 'G': 1}              519.0
# 904834           {'C': 2, 'L': 1, 'D': 2, 'G': 1}              276.0
# 912105                   {'C': 1, 'D': 2, 'G': 1}              115.0
# 934625           {'C': 2, 'L': 1, 'D': 2, 'G': 1}              155.0
# 977077           {'C': 2, 'R': 1, 'L': 2, 'D': 1}               80.0
# 1003452          {'C': 3, 'L': 1, 'D': 1, 'G': 1}             1143.0
# 1016715          {'C': 1, 'L': 2, 'D': 2, 'G': 1}               65.0
# 1138159          {'C': 2, 'L': 2, 'D': 1, 'G': 1}              202.0
# 1198111          {'C': 2, 'L': 1, 'D': 2, 'G': 1}              310.0
# 1243158          {'C': 2, 'R': 1, 'D': 2, 'G': 1}              329.0
# 1246819                          {'C': 5, 'D': 1}               88.0
# 1260658  {'C': 1, 'R': 1, 'L': 1, 'D': 2, 'G': 1}              547.0
# 1262047  {'C': 1, 'R': 1, 'L': 1, 'D': 2, 'G': 1}             1028.0
#
#                                fwd_def_a                        fwd_def_h  \
# 25893    {'FWD': 3, 'DEF': 2, 'GOAL': 1}  {'FWD': 3, 'DEF': 2, 'GOAL': 1}
# 95315    {'FWD': 3, 'DEF': 2, 'GOAL': 1}  {'FWD': 3, 'DEF': 2, 'GOAL': 1}
# 149485   {'FWD': 4, 'DEF': 1, 'GOAL': 1}  {'FWD': 2, 'DEF': 2, 'GOAL': 1}
# 263572   {'FWD': 3, 'DEF': 2, 'GOAL': 1}  {'FWD': 3, 'DEF': 2, 'GOAL': 1}
# 338102   {'FWD': 4, 'DEF': 1, 'GOAL': 1}  {'FWD': 2, 'DEF': 2, 'GOAL': 1}
# 341983   {'FWD': 3, 'DEF': 2, 'GOAL': 1}  {'FWD': 3, 'DEF': 2, 'GOAL': 1}
# 364236   {'FWD': 3, 'DEF': 2, 'GOAL': 1}  {'FWD': 3, 'DEF': 2, 'GOAL': 1}
# 394817   {'FWD': 3, 'DEF': 2, 'GOAL': 1}  {'FWD': 3, 'DEF': 2, 'GOAL': 1}
# 402275   {'FWD': 3, 'DEF': 2, 'GOAL': 1}  {'FWD': 3, 'DEF': 2, 'GOAL': 1}
# 488918   {'FWD': 3, 'DEF': 2, 'GOAL': 1}  {'FWD': 3, 'DEF': 2, 'GOAL': 1}
# 518080   {'FWD': 2, 'DEF': 2, 'GOAL': 1}  {'FWD': 3, 'DEF': 2, 'GOAL': 1}
# 536809   {'FWD': 3, 'DEF': 2, 'GOAL': 1}  {'FWD': 3, 'DEF': 2, 'GOAL': 1}
# 584485   {'FWD': 3, 'DEF': 2, 'GOAL': 1}  {'FWD': 3, 'DEF': 2, 'GOAL': 1}
# 585703   {'FWD': 2, 'DEF': 2, 'GOAL': 1}  {'FWD': 4, 'DEF': 1, 'GOAL': 1}
# 714427   {'FWD': 3, 'DEF': 2, 'GOAL': 1}  {'FWD': 3, 'DEF': 2, 'GOAL': 1}
# 870152   {'FWD': 3, 'DEF': 2, 'GOAL': 1}  {'FWD': 3, 'DEF': 2, 'GOAL': 1}
# 904834   {'FWD': 3, 'DEF': 2, 'GOAL': 1}  {'FWD': 3, 'DEF': 2, 'GOAL': 1}
# 912105   {'FWD': 3, 'DEF': 1, 'GOAL': 1}  {'FWD': 1, 'DEF': 2, 'GOAL': 1}
# 934625   {'FWD': 3, 'DEF': 2, 'GOAL': 1}  {'FWD': 3, 'DEF': 2, 'GOAL': 1}
# 977077   {'FWD': 3, 'DEF': 2, 'GOAL': 1}             {'FWD': 5, 'DEF': 1}
# 1003452  {'FWD': 2, 'DEF': 2, 'GOAL': 1}  {'FWD': 4, 'DEF': 1, 'GOAL': 1}
# 1016715  {'FWD': 3, 'DEF': 2, 'GOAL': 1}  {'FWD': 3, 'DEF': 2, 'GOAL': 1}
# 1138159  {'FWD': 2, 'DEF': 2, 'GOAL': 1}  {'FWD': 4, 'DEF': 1, 'GOAL': 1}
# 1198111  {'FWD': 3, 'DEF': 2, 'GOAL': 1}  {'FWD': 3, 'DEF': 2, 'GOAL': 1}
# 1243158  {'FWD': 3, 'DEF': 2, 'GOAL': 1}  {'FWD': 3, 'DEF': 2, 'GOAL': 1}
# 1246819  {'FWD': 3, 'DEF': 2, 'GOAL': 1}             {'FWD': 5, 'DEF': 1}
# 1260658  {'FWD': 3, 'DEF': 2, 'GOAL': 1}  {'FWD': 3, 'DEF': 2, 'GOAL': 1}
# 1262047  {'FWD': 3, 'DEF': 2, 'GOAL': 1}  {'FWD': 3, 'DEF': 2, 'GOAL': 1}
#
#                       skaters_a               skaters_h goalie_pulled_a  \
# 25893    {'SKTR': 5, 'GOAL': 1}  {'SKTR': 5, 'GOAL': 1}           False
# 95315    {'SKTR': 5, 'GOAL': 1}  {'SKTR': 5, 'GOAL': 1}           False
# 149485   {'SKTR': 5, 'GOAL': 1}  {'SKTR': 4, 'GOAL': 1}           False
# 263572   {'SKTR': 5, 'GOAL': 1}  {'SKTR': 5, 'GOAL': 1}           False
# 338102   {'SKTR': 5, 'GOAL': 1}  {'SKTR': 4, 'GOAL': 1}           False
# 341983   {'SKTR': 5, 'GOAL': 1}  {'SKTR': 5, 'GOAL': 1}           False
# 364236   {'SKTR': 5, 'GOAL': 1}  {'SKTR': 5, 'GOAL': 1}           False
# 394817   {'SKTR': 5, 'GOAL': 1}  {'SKTR': 5, 'GOAL': 1}           False
# 402275   {'SKTR': 5, 'GOAL': 1}  {'SKTR': 5, 'GOAL': 1}           False
# 488918   {'SKTR': 5, 'GOAL': 1}  {'SKTR': 5, 'GOAL': 1}           False
# 518080   {'SKTR': 4, 'GOAL': 1}  {'SKTR': 5, 'GOAL': 1}           False
# 536809   {'SKTR': 5, 'GOAL': 1}  {'SKTR': 5, 'GOAL': 1}           False
# 584485   {'SKTR': 5, 'GOAL': 1}  {'SKTR': 5, 'GOAL': 1}           False
# 585703   {'SKTR': 4, 'GOAL': 1}  {'SKTR': 5, 'GOAL': 1}           False
# 714427   {'SKTR': 5, 'GOAL': 1}  {'SKTR': 5, 'GOAL': 1}           False
# 870152   {'SKTR': 5, 'GOAL': 1}  {'SKTR': 5, 'GOAL': 1}           False
# 904834   {'SKTR': 5, 'GOAL': 1}  {'SKTR': 5, 'GOAL': 1}           False
# 912105   {'SKTR': 4, 'GOAL': 1}  {'SKTR': 3, 'GOAL': 1}           False
# 934625   {'SKTR': 5, 'GOAL': 1}  {'SKTR': 5, 'GOAL': 1}           False
# 977077   {'SKTR': 5, 'GOAL': 1}             {'SKTR': 6}           False
# 1003452  {'SKTR': 4, 'GOAL': 1}  {'SKTR': 5, 'GOAL': 1}           False
# 1016715  {'SKTR': 5, 'GOAL': 1}  {'SKTR': 5, 'GOAL': 1}           False
# 1138159  {'SKTR': 4, 'GOAL': 1}  {'SKTR': 5, 'GOAL': 1}           False
# 1198111  {'SKTR': 5, 'GOAL': 1}  {'SKTR': 5, 'GOAL': 1}           False
# 1243158  {'SKTR': 5, 'GOAL': 1}  {'SKTR': 5, 'GOAL': 1}           False
# 1246819  {'SKTR': 5, 'GOAL': 1}             {'SKTR': 6}           False
# 1260658  {'SKTR': 5, 'GOAL': 1}  {'SKTR': 5, 'GOAL': 1}           False
# 1262047  {'SKTR': 5, 'GOAL': 1}  {'SKTR': 5, 'GOAL': 1}           False
#
#         goalie_pulled_h  shot_dist event_zone    miss_type  shot_type  \
# 25893             False        NaN  Def. Zone        Block      Wrist
# 95315             False        NaN  Off. Zone        Block       Snap
# 149485            False        0.0       None         Save       Slap
# 263572            False       72.0  Off. Zone         Save      Wrist
# 338102            False        0.0        NaN          NaN        NaN
# 341983            False        0.0        NaN          NaN        NaN
# 364236            False        0.0        NaN          NaN        NaN
# 394817            False        0.0        NaN          NaN        NaN
# 402275            False        0.0       None         None  Deflected
# 488918            False       15.0  Off. Zone     Over Net      Wrist
# 518080            False        0.0       None         Save       Slap
# 536809            False        9.0  Off. Zone         None     Tip-In
# 584485            False        0.0       None         Save   Backhand
# 585703            False        0.0       None         Save      Wrist
# 714427            False       76.0  Def. Zone         Save       Snap
# 870152            False        0.0        NaN          NaN        NaN
# 904834            False        0.0        NaN          NaN        NaN
# 912105            False        0.0       None         Save       Slap
# 934625            False        0.0        NaN          NaN        NaN
# 977077             True        0.0       None  Wide of Net       Slap
# 1003452           False        0.0        NaN          NaN        NaN
# 1016715           False        0.0        NaN          NaN        NaN
# 1138159           False        NaN       None        Block       Slap
# 1198111           False        NaN  Neu. Zone        Block       Slap
# 1243158           False       48.0  Off. Zone         Save       Snap
# 1246819            True        0.0        NaN          NaN        NaN
# 1260658           False      189.0  Def. Zone         None       Snap
# 1262047           False       17.0  Off. Zone         None      Wrist
#
#          calc_dist  dist_difference
# 25893          NaN              NaN
# 95315          NaN              NaN
# 149485         NaN              NaN
# 263572         NaN              NaN
# 338102         NaN              NaN
# 341983         NaN              NaN
# 364236         NaN              NaN
# 394817         NaN              NaN
# 402275         NaN              NaN
# 488918         NaN              NaN
# 518080         NaN              NaN
# 536809         NaN              NaN
# 584485         NaN              NaN
# 585703         NaN              NaN
# 714427         NaN              NaN
# 870152         NaN              NaN
# 904834         NaN              NaN
# 912105         NaN              NaN
# 934625         NaN              NaN
# 977077         NaN              NaN
# 1003452        NaN              NaN
# 1016715        NaN              NaN
# 1138159        NaN              NaN
# 1198111        NaN              NaN
# 1243158        NaN              NaN
# 1246819        NaN              NaN
# 1260658        NaN              NaN
# 1262047        NaN              NaN

# %%
shot_frame.dropna(subset=['event_coord_x', 'event_coord_y'], inplace=True)

# %% [markdown]
# A few events from one game are missing data as to which players are on the ice. Ignore these as well.

# %%
shot_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1428328 entries, 0 to 1428367
# Data columns (total 36 columns):
#  #   Column              Non-Null Count    Dtype
# ---  ------              --------------    -----
#  0   game_id_livefeed    1428328 non-null  object
#  1   season              1428328 non-null  object
#  2   type                1428328 non-null  object
#  3   game_time           1428328 non-null  object
#  4   away_code           1428328 non-null  object
#  5   home_code           1428328 non-null  object
#  6   venue               1428328 non-null  object
#  7   period              1428328 non-null  int64
#  8   period_ord          1428328 non-null  object
#  9   period_type         1428328 non-null  object
#  10  time_elapsed        1428328 non-null  object
#  11  cum_time_elapsed    1428328 non-null  float64
#  12  event               1428328 non-null  object
#  13  event_team_code     1428328 non-null  object
#  14  event_team_is_home  1428328 non-null  bool
#  15  event_coord_x       1428328 non-null  float64
#  16  event_coord_y       1428328 non-null  float64
#  17  secondary_type      769688 non-null   object
#  18  is_rebound          1428328 non-null  object
#  19  strength            1428328 non-null  object
#  20  time_remaining      1428328 non-null  object
#  21  pos_a               1428324 non-null  object
#  22  pos_h               1428324 non-null  object
#  23  seconds_remaining   1428328 non-null  float64
#  24  fwd_def_a           1428324 non-null  object
#  25  fwd_def_h           1428324 non-null  object
#  26  skaters_a           1428324 non-null  object
#  27  skaters_h           1428324 non-null  object
#  28  goalie_pulled_a     1428324 non-null  object
#  29  goalie_pulled_h     1428324 non-null  object
#  30  shot_dist           1066161 non-null  float64
#  31  event_zone          1428328 non-null  object
#  32  miss_type           1359107 non-null  object
#  33  shot_type           1428235 non-null  object
#  34  calc_dist           1428328 non-null  float64
#  35  dist_difference     1066161 non-null  float64
# dtypes: bool(1), float64(7), int64(1), object(27)
# memory usage: 393.7+ MB

# %%
shot_frame[shot_frame['pos_a'].isna() | shot_frame['pos_h'].isna()]
# Out:
#         game_id_livefeed    season type             game_time away_code  \
# 1412138       2019020876  20192020    R  2020-03-12T02:00:00Z       STL
# 1412139       2019020876  20192020    R  2020-03-12T02:00:00Z       STL
# 1412140       2019020876  20192020    R  2020-03-12T02:00:00Z       STL
# 1412141       2019020876  20192020    R  2020-03-12T02:00:00Z       STL
#
#         home_code         venue  period period_ord period_type time_elapsed  \
# 1412138       ANA  Honda Center       1        1st     REGULAR        00:00
# 1412139       ANA  Honda Center       1        1st     REGULAR        00:00
# 1412140       ANA  Honda Center       1        1st     REGULAR        00:00
# 1412141       ANA  Honda Center       1        1st     REGULAR        00:00
#
#          cum_time_elapsed event event_team_code  event_team_is_home  \
# 1412138               0.0  GOAL             ANA                True
# 1412139               0.0  GOAL             ANA                True
# 1412140               0.0  GOAL             STL               False
# 1412141               0.0  GOAL             STL               False
#
#          event_coord_x  event_coord_y secondary_type is_rebound strength  \
# 1412138           57.0          -14.0           None      False       EV
# 1412139           57.0          -14.0           None      False       EV
# 1412140           57.0          -26.0           None       True       EV
# 1412141           57.0          -26.0           None       True       EV
#
#         time_remaining pos_a pos_h  seconds_remaining fwd_def_a fwd_def_h  \
# 1412138          20:00  None  None             1200.0      None      None
# 1412139          20:00  None  None             1200.0      None      None
# 1412140          20:00  None  None             1200.0      None      None
# 1412141          20:00  None  None             1200.0      None      None
#
#         skaters_a skaters_h goalie_pulled_a goalie_pulled_h  shot_dist  \
# 1412138      None      None            None            None       34.0
# 1412139      None      None            None            None       41.0
# 1412140      None      None            None            None       34.0
# 1412141      None      None            None            None       41.0
#
#         event_zone miss_type shot_type  calc_dist  dist_difference
# 1412138  Off. Zone      None      None  34.928498         0.928498
# 1412139  Off. Zone      None      None  34.928498         6.071502
# 1412140  Off. Zone      None      None  41.231056         7.231056
# 1412141  Off. Zone      None      None  41.231056         0.231056

# %%
shot_frame.dropna(subset=['pos_a', 'pos_h'], inplace=True)

# %% [markdown]
# There are a handful of remaining fields with null entries. These are `secondary_type`, `shot_dist`, `miss_type`, `shot_type`, and `dist_difference`. The construction of `dist_difference` means that it's only defined when `shot_dist` is defined. Of the others, `shot_dist` is known to be missing when the event type is `BLOCK`. The `miss_type` is missing when the event type is `GOAL`.

# %%
shot_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1428324 entries, 0 to 1428367
# Data columns (total 36 columns):
#  #   Column              Non-Null Count    Dtype
# ---  ------              --------------    -----
#  0   game_id_livefeed    1428324 non-null  object
#  1   season              1428324 non-null  object
#  2   type                1428324 non-null  object
#  3   game_time           1428324 non-null  object
#  4   away_code           1428324 non-null  object
#  5   home_code           1428324 non-null  object
#  6   venue               1428324 non-null  object
#  7   period              1428324 non-null  int64
#  8   period_ord          1428324 non-null  object
#  9   period_type         1428324 non-null  object
#  10  time_elapsed        1428324 non-null  object
#  11  cum_time_elapsed    1428324 non-null  float64
#  12  event               1428324 non-null  object
#  13  event_team_code     1428324 non-null  object
#  14  event_team_is_home  1428324 non-null  bool
#  15  event_coord_x       1428324 non-null  float64
#  16  event_coord_y       1428324 non-null  float64
#  17  secondary_type      769688 non-null   object
#  18  is_rebound          1428324 non-null  object
#  19  strength            1428324 non-null  object
#  20  time_remaining      1428324 non-null  object
#  21  pos_a               1428324 non-null  object
#  22  pos_h               1428324 non-null  object
#  23  seconds_remaining   1428324 non-null  float64
#  24  fwd_def_a           1428324 non-null  object
#  25  fwd_def_h           1428324 non-null  object
#  26  skaters_a           1428324 non-null  object
#  27  skaters_h           1428324 non-null  object
#  28  goalie_pulled_a     1428324 non-null  object
#  29  goalie_pulled_h     1428324 non-null  object
#  30  shot_dist           1066157 non-null  float64
#  31  event_zone          1428324 non-null  object
#  32  miss_type           1359107 non-null  object
#  33  shot_type           1428235 non-null  object
#  34  calc_dist           1428324 non-null  float64
#  35  dist_difference     1066157 non-null  float64
# dtypes: bool(1), float64(7), int64(1), object(27)
# memory usage: 393.7+ MB

# %% [markdown]
# Checking miss-type to confirm that it should only be missing when the event type is `GOAL`. There are three miss events which don't have a miss-type. This shouldn't pose a major concern, so these will be marked as `Miss`. To eliminate null entries, goals will be marked as miss-type `Goal`.

# %%
shot_frame['miss_type'].value_counts()
# Out:
# Save            700536
# Block           362167
# Wide of Net     251564
# Over Net         29796
# Goalpost         12634
# Hit Crossbar      2410
# Name: miss_type, dtype: int64

# %%
shot_frame[shot_frame['event']=='GOAL']['miss_type'].value_counts()
# Out:
# Series([], Name: miss_type, dtype: int64)

# %%
shot_frame[shot_frame['miss_type'].isna()]['event'].value_counts()
# Out:
# GOAL    69214
# MISS        3
# Name: event, dtype: int64

# %%
shot_frame[(shot_frame['miss_type'].isna()) & (shot_frame['event']=='MISS')]
# Out:
#        game_id_livefeed    season type             game_time away_code  \
# 152513       2011020055  20112012    R  2011-10-15T23:00:00Z       WPG
# 436420       2013020524  20132014    R  2013-12-20T00:00:00Z       PHX
# 645476       2014021068  20142015    R  2015-03-21T20:00:00Z       VAN
#
#        home_code              venue  period period_ord period_type  \
# 152513       PHX   Jobing.com Arena       3        3rd     REGULAR
# 436420       TOR  Air Canada Centre       4         OT    OVERTIME
# 645476       LAK     STAPLES Center       3        3rd     REGULAR
#
#        time_elapsed  cum_time_elapsed event event_team_code  \
# 152513        12:22            3142.0  MISS             PHX
# 436420        03:04            3784.0  MISS             PHX
# 645476        19:37            3577.0  MISS             LAK
#
#         event_team_is_home  event_coord_x  event_coord_y secondary_type  \
# 152513                True           80.0            0.0           None
# 436420               False           35.0          -11.0           None
# 645476                True           81.0           -4.0           None
#
#        is_rebound strength time_remaining                             pos_a  \
# 152513      False       PP          07:38  {'R': 1, 'L': 1, 'D': 2, 'G': 1}
# 436420      False       EV          01:56  {'C': 1, 'R': 1, 'D': 2, 'G': 1}
# 645476       True       PP          00:23          {'C': 2, 'D': 2, 'G': 1}
#
#                                    pos_h  seconds_remaining  \
# 152513  {'C': 2, 'L': 2, 'D': 1, 'G': 1}              458.0
# 436420  {'C': 1, 'R': 1, 'D': 2, 'G': 1}              116.0
# 645476  {'C': 2, 'R': 1, 'L': 1, 'D': 2}               23.0
#
#                               fwd_def_a                        fwd_def_h  \
# 152513  {'FWD': 2, 'DEF': 2, 'GOAL': 1}  {'FWD': 4, 'DEF': 1, 'GOAL': 1}
# 436420  {'FWD': 2, 'DEF': 2, 'GOAL': 1}  {'FWD': 2, 'DEF': 2, 'GOAL': 1}
# 645476  {'FWD': 2, 'DEF': 2, 'GOAL': 1}             {'FWD': 4, 'DEF': 2}
#
#                      skaters_a               skaters_h goalie_pulled_a  \
# 152513  {'SKTR': 4, 'GOAL': 1}  {'SKTR': 5, 'GOAL': 1}           False
# 436420  {'SKTR': 4, 'GOAL': 1}  {'SKTR': 4, 'GOAL': 1}           False
# 645476  {'SKTR': 4, 'GOAL': 1}             {'SKTR': 6}           False
#
#        goalie_pulled_h  shot_dist event_zone miss_type shot_type  calc_dist  \
# 152513           False       10.0  Off. Zone      None    Tip-In   9.000000
# 436420           False       56.0  Off. Zone      None     Wrist  55.108983
# 645476            True        9.0  Off. Zone      None     Wrist   8.944272
#
#         dist_difference
# 152513         1.000000
# 436420         0.891017
# 645476         0.055728

# %%
shot_frame.loc[(shot_frame['miss_type'].isna()) & (shot_frame['event']=='MISS'), 'miss_type'] = 'Miss'

# %%
shot_frame[(shot_frame['miss_type'].isna()) & (shot_frame['event']=='MISS')]
# Out:
# Empty DataFrame
# Columns: [game_id_livefeed, season, type, game_time, away_code, home_code, venue, period, period_ord, period_type, time_elapsed, cum_time_elapsed, event, event_team_code, event_team_is_home, event_coord_x, event_coord_y, secondary_type, is_rebound, strength, time_remaining, pos_a, pos_h, seconds_remaining, fwd_def_a, fwd_def_h, skaters_a, skaters_h, goalie_pulled_a, goalie_pulled_h, shot_dist, event_zone, miss_type, shot_type, calc_dist, dist_difference]
# Index: []

# %%
shot_frame[(shot_frame['miss_type'].isna())]['event'].value_counts()
# Out:
# GOAL    69214
# Name: event, dtype: int64

# %%
shot_frame[(shot_frame['miss_type'].isna())].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 69214 entries, 3 to 1428299
# Data columns (total 36 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   game_id_livefeed    69214 non-null  object
#  1   season              69214 non-null  object
#  2   type                69214 non-null  object
#  3   game_time           69214 non-null  object
#  4   away_code           69214 non-null  object
#  5   home_code           69214 non-null  object
#  6   venue               69214 non-null  object
#  7   period              69214 non-null  int64
#  8   period_ord          69214 non-null  object
#  9   period_type         69214 non-null  object
#  10  time_elapsed        69214 non-null  object
#  11  cum_time_elapsed    69214 non-null  float64
#  12  event               69214 non-null  object
#  13  event_team_code     69214 non-null  object
#  14  event_team_is_home  69214 non-null  bool
#  15  event_coord_x       69214 non-null  float64
#  16  event_coord_y       69214 non-null  float64
#  17  secondary_type      69171 non-null  object
#  18  is_rebound          69214 non-null  object
#  19  strength            69214 non-null  object
#  20  time_remaining      69214 non-null  object
#  21  pos_a               69214 non-null  object
#  22  pos_h               69214 non-null  object
#  23  seconds_remaining   69214 non-null  float64
#  24  fwd_def_a           69214 non-null  object
#  25  fwd_def_h           69214 non-null  object
#  26  skaters_a           69214 non-null  object
#  27  skaters_h           69214 non-null  object
#  28  goalie_pulled_a     69214 non-null  object
#  29  goalie_pulled_h     69214 non-null  object
#  30  shot_dist           69214 non-null  float64
#  31  event_zone          69214 non-null  object
#  32  miss_type           0 non-null      object
#  33  shot_type           69163 non-null  object
#  34  calc_dist           69214 non-null  float64
#  35  dist_difference     69214 non-null  float64
# dtypes: bool(1), float64(7), int64(1), object(27)
# memory usage: 19.1+ MB

# %%
shot_frame.loc[(shot_frame['miss_type'].isna()), 'miss_type'] = 'Goal'

# %%
shot_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1428324 entries, 0 to 1428367
# Data columns (total 36 columns):
#  #   Column              Non-Null Count    Dtype
# ---  ------              --------------    -----
#  0   game_id_livefeed    1428324 non-null  object
#  1   season              1428324 non-null  object
#  2   type                1428324 non-null  object
#  3   game_time           1428324 non-null  object
#  4   away_code           1428324 non-null  object
#  5   home_code           1428324 non-null  object
#  6   venue               1428324 non-null  object
#  7   period              1428324 non-null  int64
#  8   period_ord          1428324 non-null  object
#  9   period_type         1428324 non-null  object
#  10  time_elapsed        1428324 non-null  object
#  11  cum_time_elapsed    1428324 non-null  float64
#  12  event               1428324 non-null  object
#  13  event_team_code     1428324 non-null  object
#  14  event_team_is_home  1428324 non-null  bool
#  15  event_coord_x       1428324 non-null  float64
#  16  event_coord_y       1428324 non-null  float64
#  17  secondary_type      769688 non-null   object
#  18  is_rebound          1428324 non-null  object
#  19  strength            1428324 non-null  object
#  20  time_remaining      1428324 non-null  object
#  21  pos_a               1428324 non-null  object
#  22  pos_h               1428324 non-null  object
#  23  seconds_remaining   1428324 non-null  float64
#  24  fwd_def_a           1428324 non-null  object
#  25  fwd_def_h           1428324 non-null  object
#  26  skaters_a           1428324 non-null  object
#  27  skaters_h           1428324 non-null  object
#  28  goalie_pulled_a     1428324 non-null  object
#  29  goalie_pulled_h     1428324 non-null  object
#  30  shot_dist           1066157 non-null  float64
#  31  event_zone          1428324 non-null  object
#  32  miss_type           1428324 non-null  object
#  33  shot_type           1428235 non-null  object
#  34  calc_dist           1428324 non-null  float64
#  35  dist_difference     1066157 non-null  float64
# dtypes: bool(1), float64(7), int64(1), object(27)
# memory usage: 393.7+ MB

# %% [markdown]
# Now, confirm that the missing `shot_dist`/`dist_difference` entries occur for blocks.

# %%
shot_frame[shot_frame['shot_dist'].isna()]['event'].value_counts()
# Out:
# BLOCK    362167
# Name: event, dtype: int64

# %%
shot_frame['event'].value_counts()
# Out:
# SHOT     700536
# BLOCK    362167
# MISS     296407
# GOAL      69214
# Name: event, dtype: int64

# %% [markdown]
# The field `secondary_type` carries the shot-type from the live game feeds. However, this is omitted from the feeds for blocks and misses. It is missing from a handful of additional events as well.

# %%
shot_frame[shot_frame['secondary_type'].isna()]['event'].value_counts()
# Out:
# BLOCK    362167
# MISS     296407
# GOAL         43
# SHOT         19
# Name: event, dtype: int64

# %% [markdown]
# The field `shot_type` is obtained from the HTML play-by-play report. This is missing for a handful of events.

# %%
shot_frame[shot_frame['shot_type'].isna()]['event'].value_counts()
# Out:
# GOAL     51
# SHOT     19
# BLOCK    16
# MISS      3
# Name: event, dtype: int64

# %% [markdown]
# Most of the shot-types missing from the play-by-play are also missing from the live feed. These will be left alone for now.

# %%
shot_frame[(shot_frame['secondary_type'].isna()) & (shot_frame['shot_type'].isna())]['event'].value_counts()
# Out:
# GOAL     43
# SHOT     19
# BLOCK    16
# MISS      3
# Name: event, dtype: int64

# %%
shot_frame[(~shot_frame['secondary_type'].isna()) & (shot_frame['shot_type'].isna()) & (shot_frame['event'] == 'GOAL')]
# Out:
#         game_id_livefeed    season type             game_time away_code  \
# 981106        2017020083  20172018    R  2017-10-17T23:00:00Z       FLA
# 997522        2017020222  20172018    R  2017-11-07T03:00:00Z       DET
# 1064542       2017020791  20172018    R  2018-02-03T01:00:00Z       VGK
# 1076528       2017020891  20172018    R  2018-02-17T00:30:00Z       NYI
# 1124303       2017030153  20172018    P  2018-04-17T02:00:00Z       NSH
# 1152013       2018020173  20182019    R  2018-10-31T00:00:00Z       VGK
# 1153685       2018020187  20182019    R  2018-11-02T01:00:00Z       COL
# 1155919       2018020206  20182019    R  2018-11-04T02:30:00Z       PHI
#
#         home_code                   venue  period period_ord period_type  \
# 981106        PHI      Wells Fargo Center       3        3rd     REGULAR
# 997522        VAN            Rogers Arena       2        2nd     REGULAR
# 1064542       MIN      Xcel Energy Center       3        3rd     REGULAR
# 1076528       CAR               PNC Arena       3        3rd     REGULAR
# 1124303       COL            Pepsi Center       3        3rd     REGULAR
# 1152013       NSH       Bridgestone Arena       3        3rd     REGULAR
# 1153685       CGY   Scotiabank Saddledome       3        3rd     REGULAR
# 1155919       SJS  SAP Center at San Jose       4         OT    OVERTIME
#
#         time_elapsed  cum_time_elapsed event event_team_code  \
# 981106         18:23            3503.0  GOAL             PHI
# 997522         15:15            2115.0  GOAL             DET
# 1064542        18:31            3511.0  GOAL             MIN
# 1076528        19:28            3568.0  GOAL             NYI
# 1124303        18:24            3504.0  GOAL             COL
# 1152013        17:42            3462.0  GOAL             NSH
# 1153685        18:57            3537.0  GOAL             COL
# 1155919        00:13            3613.0  GOAL             SJS
#
#          event_team_is_home  event_coord_x  event_coord_y secondary_type  \
# 981106                 True          -22.0           23.0     Wrist Shot
# 997522                False           74.0            2.0     Wrist Shot
# 1064542                True           40.0          -16.0     Wrist Shot
# 1076528               False           67.0          -23.0     Wrist Shot
# 1124303                True           75.0           -7.0     Wrist Shot
# 1152013                True           79.0            1.0     Wrist Shot
# 1153685               False           81.0            1.0     Wrist Shot
# 1155919                True           61.0           -9.0     Wrist Shot
#
#         is_rebound strength time_remaining                             pos_a  \
# 981106       False       EV          01:37  {'C': 1, 'R': 2, 'L': 1, 'D': 2}
# 997522       False       PP          04:45  {'C': 2, 'R': 2, 'D': 1, 'G': 1}
# 1064542      False       EV          01:29  {'C': 1, 'R': 1, 'L': 3, 'D': 1}
# 1076528      False       EV          00:32          {'C': 3, 'D': 2, 'G': 1}
# 1124303      False       EV          01:36          {'C': 2, 'L': 2, 'D': 2}
# 1152013      False       EV          02:18          {'C': 2, 'L': 2, 'D': 2}
# 1153685       True       PP          01:03  {'C': 3, 'R': 1, 'L': 1, 'D': 1}
# 1155919      False       EV          04:47          {'R': 2, 'D': 1, 'G': 1}
#
#                                             pos_h  seconds_remaining  \
# 981106           {'C': 1, 'L': 2, 'D': 2, 'G': 1}               97.0
# 997522           {'C': 1, 'R': 1, 'D': 2, 'G': 1}              285.0
# 1064542  {'C': 1, 'R': 1, 'L': 1, 'D': 2, 'G': 1}               89.0
# 1076528          {'C': 3, 'R': 1, 'L': 1, 'D': 1}               32.0
# 1124303  {'C': 1, 'R': 1, 'L': 1, 'D': 2, 'G': 1}               96.0
# 1152013          {'C': 1, 'L': 2, 'D': 2, 'G': 1}              138.0
# 1153685                  {'C': 2, 'D': 2, 'G': 1}               63.0
# 1155919          {'C': 1, 'R': 1, 'D': 1, 'G': 1}              287.0
#
#                                fwd_def_a                        fwd_def_h  \
# 981106              {'FWD': 4, 'DEF': 2}  {'FWD': 3, 'DEF': 2, 'GOAL': 1}
# 997522   {'FWD': 4, 'DEF': 1, 'GOAL': 1}  {'FWD': 2, 'DEF': 2, 'GOAL': 1}
# 1064542             {'FWD': 5, 'DEF': 1}  {'FWD': 3, 'DEF': 2, 'GOAL': 1}
# 1076528  {'FWD': 3, 'DEF': 2, 'GOAL': 1}             {'FWD': 5, 'DEF': 1}
# 1124303             {'FWD': 4, 'DEF': 2}  {'FWD': 3, 'DEF': 2, 'GOAL': 1}
# 1152013             {'FWD': 4, 'DEF': 2}  {'FWD': 3, 'DEF': 2, 'GOAL': 1}
# 1153685             {'FWD': 5, 'DEF': 1}  {'FWD': 2, 'DEF': 2, 'GOAL': 1}
# 1155919  {'FWD': 2, 'DEF': 1, 'GOAL': 1}  {'FWD': 2, 'DEF': 1, 'GOAL': 1}
#
#                       skaters_a               skaters_h goalie_pulled_a  \
# 981106              {'SKTR': 6}  {'SKTR': 5, 'GOAL': 1}            True
# 997522   {'SKTR': 5, 'GOAL': 1}  {'SKTR': 4, 'GOAL': 1}           False
# 1064542             {'SKTR': 6}  {'SKTR': 5, 'GOAL': 1}            True
# 1076528  {'SKTR': 5, 'GOAL': 1}             {'SKTR': 6}           False
# 1124303             {'SKTR': 6}  {'SKTR': 5, 'GOAL': 1}            True
# 1152013             {'SKTR': 6}  {'SKTR': 5, 'GOAL': 1}            True
# 1153685             {'SKTR': 6}  {'SKTR': 4, 'GOAL': 1}            True
# 1155919  {'SKTR': 3, 'GOAL': 1}  {'SKTR': 3, 'GOAL': 1}           False
#
#         goalie_pulled_h  shot_dist event_zone miss_type shot_type   calc_dist  \
# 981106            False      113.0  Neu. Zone      Goal      None  113.357840
# 997522            False       16.0  Off. Zone      Goal      None   15.132746
# 1064542           False       52.0  Off. Zone      Goal      None   51.546096
# 1076528            True       32.0  Off. Zone      Goal      None   31.827661
# 1124303           False       16.0  Off. Zone      Goal      None   15.652476
# 1152013           False       11.0  Off. Zone      Goal      None   10.049876
# 1153685           False        9.0  Off. Zone      Goal      None    8.062258
# 1155919           False       30.0  Off. Zone      Goal      None   29.410882
#
#          dist_difference
# 981106          0.357840
# 997522          0.867254
# 1064542         0.453904
# 1076528         0.172339
# 1124303         0.347524
# 1152013         0.950124
# 1153685         0.937742
# 1155919         0.589118

# %% [markdown]
# The positions fields give the positions of players on ice at any time. Generally speaking, the number of players/attackers/forwards on the ice is more important, rather than the specific positions.

# %%
shot_frame['players_h'] = shot_frame['pos_h'].apply(lambda x: len(list(x.elements())))
shot_frame['players_a'] = shot_frame['pos_a'].apply(lambda x: len(list(x.elements())))
shot_frame['skaters_h'] = shot_frame['skaters_h'].apply(lambda x: x['SKTR'])
shot_frame['skaters_a'] = shot_frame['skaters_a'].apply(lambda x: x['SKTR'])
shot_frame['fwds_h'] = shot_frame['fwd_def_h'].apply(lambda x: x['FWD'])
shot_frame['fwds_a'] = shot_frame['fwd_def_a'].apply(lambda x: x['FWD'])

# %%
shot_frame.head()
# Out:
#   game_id_livefeed    season type             game_time away_code home_code  \
# 0       2010020003  20102011    R  2010-10-07T16:00:00Z       CAR       MIN
# 1       2010020003  20102011    R  2010-10-07T16:00:00Z       CAR       MIN
# 2       2010020003  20102011    R  2010-10-07T16:00:00Z       CAR       MIN
# 3       2010020003  20102011    R  2010-10-07T16:00:00Z       CAR       MIN
# 4       2010020003  20102011    R  2010-10-07T16:00:00Z       CAR       MIN
#
#              venue  period period_ord period_type time_elapsed  \
# 0  Hartwall Areena       1        1st     REGULAR        01:05
# 1  Hartwall Areena       1        1st     REGULAR        01:16
# 2  Hartwall Areena       1        1st     REGULAR        01:37
# 3  Hartwall Areena       1        1st     REGULAR        03:33
# 4  Hartwall Areena       1        1st     REGULAR        03:49
#
#    cum_time_elapsed  event event_team_code  event_team_is_home  event_coord_x  \
# 0              65.0   SHOT             CAR               False           56.0
# 1              76.0   MISS             CAR               False           35.0
# 2              97.0   MISS             MIN                True           87.0
# 3             213.0   GOAL             MIN                True           78.0
# 4             229.0  BLOCK             MIN                True           77.0
#
#    event_coord_y secondary_type is_rebound strength time_remaining  \
# 0          -15.0      Snap Shot      False       EV          18:55
# 1           33.0           None      False       EV          18:44
# 2           -6.0           None      False       EV          18:23
# 3            3.0     Wrist Shot      False       EV          16:27
# 4           13.0           None      False       EV          16:11
#
#                                       pos_a  \
# 0  {'C': 1, 'R': 1, 'L': 1, 'D': 2, 'G': 1}
# 1  {'C': 1, 'R': 1, 'L': 1, 'D': 2, 'G': 1}
# 2  {'C': 1, 'R': 1, 'L': 1, 'D': 2, 'G': 1}
# 3  {'C': 1, 'R': 1, 'L': 1, 'D': 2, 'G': 1}
# 4  {'C': 1, 'R': 1, 'L': 1, 'D': 2, 'G': 1}
#
#                                       pos_h  seconds_remaining  \
# 0          {'C': 1, 'R': 2, 'D': 2, 'G': 1}             1135.0
# 1          {'C': 1, 'R': 2, 'D': 2, 'G': 1}             1124.0
# 2  {'C': 1, 'R': 1, 'L': 1, 'D': 2, 'G': 1}             1103.0
# 3          {'C': 2, 'L': 1, 'D': 2, 'G': 1}              987.0
# 4  {'C': 1, 'R': 1, 'L': 1, 'D': 2, 'G': 1}              971.0
#
#                          fwd_def_a                        fwd_def_h  \
# 0  {'FWD': 3, 'DEF': 2, 'GOAL': 1}  {'FWD': 3, 'DEF': 2, 'GOAL': 1}
# 1  {'FWD': 3, 'DEF': 2, 'GOAL': 1}  {'FWD': 3, 'DEF': 2, 'GOAL': 1}
# 2  {'FWD': 3, 'DEF': 2, 'GOAL': 1}  {'FWD': 3, 'DEF': 2, 'GOAL': 1}
# 3  {'FWD': 3, 'DEF': 2, 'GOAL': 1}  {'FWD': 3, 'DEF': 2, 'GOAL': 1}
# 4  {'FWD': 3, 'DEF': 2, 'GOAL': 1}  {'FWD': 3, 'DEF': 2, 'GOAL': 1}
#
#    skaters_a  skaters_h goalie_pulled_a goalie_pulled_h  shot_dist event_zone  \
# 0          5          5           False           False       37.0  Off. Zone
# 1          5          5           False           False       64.0  Off. Zone
# 2          5          5           False           False        6.0  Off. Zone
# 3          5          5           False           False       12.0  Off. Zone
# 4          5          5           False           False        NaN  Off. Zone
#
#      miss_type shot_type  calc_dist  dist_difference  players_h  players_a  \
# 0         Save      Snap  36.249138         0.750862          6          6
# 1  Wide of Net     Wrist  63.285069         0.714931          6          6
# 2  Wide of Net     Wrist   6.324555         0.324555          6          6
# 3         Goal     Wrist  11.401754         0.598246          6          6
# 4        Block      Snap  17.691806              NaN          6          6
#
#    fwds_h  fwds_a
# 0       3       3
# 1       3       3
# 2       3       3
# 3       3       3
# 4       3       3

# %%
shot_frame.drop(['pos_h', 'pos_a', 'fwd_def_a', 'fwd_def_h'], axis=1, inplace=True)

# %%
shot_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1428324 entries, 0 to 1428367
# Data columns (total 36 columns):
#  #   Column              Non-Null Count    Dtype
# ---  ------              --------------    -----
#  0   game_id_livefeed    1428324 non-null  object
#  1   season              1428324 non-null  object
#  2   type                1428324 non-null  object
#  3   game_time           1428324 non-null  object
#  4   away_code           1428324 non-null  object
#  5   home_code           1428324 non-null  object
#  6   venue               1428324 non-null  object
#  7   period              1428324 non-null  int64
#  8   period_ord          1428324 non-null  object
#  9   period_type         1428324 non-null  object
#  10  time_elapsed        1428324 non-null  object
#  11  cum_time_elapsed    1428324 non-null  float64
#  12  event               1428324 non-null  object
#  13  event_team_code     1428324 non-null  object
#  14  event_team_is_home  1428324 non-null  bool
#  15  event_coord_x       1428324 non-null  float64
#  16  event_coord_y       1428324 non-null  float64
#  17  secondary_type      769688 non-null   object
#  18  is_rebound          1428324 non-null  object
#  19  strength            1428324 non-null  object
#  20  time_remaining      1428324 non-null  object
#  21  seconds_remaining   1428324 non-null  float64
#  22  skaters_a           1428324 non-null  int64
#  23  skaters_h           1428324 non-null  int64
#  24  goalie_pulled_a     1428324 non-null  object
#  25  goalie_pulled_h     1428324 non-null  object
#  26  shot_dist           1066157 non-null  float64
#  27  event_zone          1428324 non-null  object
#  28  miss_type           1428324 non-null  object
#  29  shot_type           1428235 non-null  object
#  30  calc_dist           1428324 non-null  float64
#  31  dist_difference     1066157 non-null  float64
#  32  players_h           1428324 non-null  int64
#  33  players_a           1428324 non-null  int64
#  34  fwds_h              1428324 non-null  int64
#  35  fwds_a              1428324 non-null  int64
# dtypes: bool(1), float64(7), int64(7), object(21)
# memory usage: 393.7+ MB

# %% [markdown]
# Several fields: `is_rebound`, `goalie_pulled_a`, and `goalie_pulled_h` should be boolean-valued.

# %%
shot_frame['is_rebound'] = shot_frame['is_rebound'].astype(bool)
shot_frame['goalie_pulled_a'] = shot_frame['goalie_pulled_a'].astype(bool)
shot_frame['goalie_pulled_h'] = shot_frame['goalie_pulled_h'].astype(bool)

# %%
shot_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1428324 entries, 0 to 1428367
# Data columns (total 36 columns):
#  #   Column              Non-Null Count    Dtype
# ---  ------              --------------    -----
#  0   game_id_livefeed    1428324 non-null  object
#  1   season              1428324 non-null  object
#  2   type                1428324 non-null  object
#  3   game_time           1428324 non-null  object
#  4   away_code           1428324 non-null  object
#  5   home_code           1428324 non-null  object
#  6   venue               1428324 non-null  object
#  7   period              1428324 non-null  int64
#  8   period_ord          1428324 non-null  object
#  9   period_type         1428324 non-null  object
#  10  time_elapsed        1428324 non-null  object
#  11  cum_time_elapsed    1428324 non-null  float64
#  12  event               1428324 non-null  object
#  13  event_team_code     1428324 non-null  object
#  14  event_team_is_home  1428324 non-null  bool
#  15  event_coord_x       1428324 non-null  float64
#  16  event_coord_y       1428324 non-null  float64
#  17  secondary_type      769688 non-null   object
#  18  is_rebound          1428324 non-null  bool
#  19  strength            1428324 non-null  object
#  20  time_remaining      1428324 non-null  object
#  21  seconds_remaining   1428324 non-null  float64
#  22  skaters_a           1428324 non-null  int64
#  23  skaters_h           1428324 non-null  int64
#  24  goalie_pulled_a     1428324 non-null  bool
#  25  goalie_pulled_h     1428324 non-null  bool
#  26  shot_dist           1066157 non-null  float64
#  27  event_zone          1428324 non-null  object
#  28  miss_type           1428324 non-null  object
#  29  shot_type           1428235 non-null  object
#  30  calc_dist           1428324 non-null  float64
#  31  dist_difference     1066157 non-null  float64
#  32  players_h           1428324 non-null  int64
#  33  players_a           1428324 non-null  int64
#  34  fwds_h              1428324 non-null  int64
#  35  fwds_a              1428324 non-null  int64
# dtypes: bool(4), float64(7), int64(7), object(18)
# memory usage: 365.1+ MB

# %%
current_dir = Path.cwd()
relative_path = 'data/cleaned.pkl'
frame_path = current_dir.joinpath(relative_path)
shot_frame.to_pickle(str(frame_path))

# %% [markdown]
# ## Analysis of Shot Location

# %% [markdown]
# ### Shot-Angles
# Next, introduce the shot-angle. This measures the angular distance between the shot (as measured from the location of the event to the center of the goal line, located at $(89,0)$) and the $x$-axis. Shots with negative $y$-coordinate are taken to have negative angles. The angle is measured in degrees and should lie between -180 and 180.

# %%
shot_frame['calc_angle'] = np.arctan2(shot_frame['event_coord_y'], 89 - shot_frame['event_coord_x']) * 180 / np.pi
shot_frame['calc_angle'].describe()
# Out:
# count    1.428324e+06
# mean    -1.056570e+00
# std      3.482789e+01
# min     -1.800000e+02
# 25%     -2.740758e+01
# 50%      0.000000e+00
# 75%      2.582099e+01
# max      1.800000e+02
# Name: calc_angle, dtype: float64

# %% [markdown]
# ### Shot-Location Adjustments
# The shot-location data is well-known to have an arena bias (see e.g. Schnuckers and Curro at http://statsportsconsulting.com/main/wp-content/uploads/Schuckers_Curro_MIT_Sloan_THoR.pdf). Madison Square Garden is considered to be oe of the stronger outliers.

# %%
shot_frame['calc_dist'].describe()
# Out:
# count    1.428324e+06
# mean     3.373279e+01
# std      2.074509e+01
# min      0.000000e+00
# 25%      1.788854e+01
# 50%      3.087070e+01
# 75%      4.617359e+01
# max      1.926344e+02
# Name: calc_dist, dtype: float64

# %% [markdown]
# The mean shot distance at Madison Square Garden is 4 feet closer to the net than in the full set. The median distance is 6 feet closer.

# %%
shot_frame[shot_frame['venue']=='Madison Square Garden']['calc_dist'].describe()
# Out:
# count    49132.000000
# mean        29.666476
# std         20.650588
# min          0.000000
# 25%         14.142136
# 50%         24.515301
# 75%         41.593269
# max        187.416648
# Name: calc_dist, dtype: float64

# %% [markdown]
# The article by Schnuckers and Curro provides a method for adjusting coordinates to account for the bias.
# Each coordinate is adjusted independently. For a coordinate, the empirical distribution functions $F$ and $F_A$ are calculated, where $F$ is the CDF of all shot coordinates and $F_A$ is the CDF looking at all shot coordinates where the shot was taken by the visiting team. There are a handful of neutral-site venues. In these games, the away-team was chosen to be the team determined by the NHL to be the visiting team for that game.
# In a similar fashion, empirical distribution functions $F_V$ and $F_{VA}$ are calculated for each venue independently. Here, $F_V$ is the CDF for all shots at that venue and $F_{VA}$ is the CDF for all shots by the designated visiting team at that venue.
# Using these ECDFs, an adjusted quantile `q` is calculated for each coordinate `c` to be $q(c) = F_V(c) - (F_{VA}(c) - F_A(c)).$  This quantile is adjusted to be in the interval $[0,1]$ by taking $q'(c) = \min(\max(q(c), 0), 1).$ Finally, the adjusted coordinate `c'` is calculated by $F^{-1}(q')$ using linear interpolation. The adjusted coordinates are assigned to variables `adj_x` and `adj_y`. Note: Schnuckers/Curro don't use linear interpolation (or any interpolation), however they suggest using a smoothed version of the ECDF.

# %%
venue_list = list(shot_frame['venue'].unique())
venue_all = {}
venue_away = {}
for venue in venue_list:
    venue_shots = shot_frame[shot_frame['venue']==venue]
    x_coord = ECDF(list(venue_shots['event_coord_x']))
    y_coord = ECDF(list(venue_shots['event_coord_y']))
    venue_all[venue] = {'x': x_coord, 'y': y_coord}
    venue_away_shots = venue_shots[venue_shots['event_team_is_home']==False]
    x_coord = ECDF(list(venue_away_shots['event_coord_x']))
    y_coord = ECDF(list(venue_away_shots['event_coord_y']))
    venue_away[venue] = {'x': x_coord, 'y': y_coord}
away_shots = shot_frame[shot_frame['event_team_is_home']==False]
x_coord = ECDF(list(away_shots['event_coord_x']))
y_coord = ECDF(list(away_shots['event_coord_y']))
venue_away['all'] = {'x': x_coord, 'y': y_coord}
sorted_x = shot_frame['event_coord_x'].sort_values()
sorted_y = shot_frame['event_coord_y'].sort_values()

# %% [markdown]
# <b>Warning!</b> The following cells may take several hours to run.

# %%
adjusted_frame = shot_frame
adjusted_frame['f_vx'] = adjusted_frame.apply(lambda row : venue_all[row['venue']]['x'](row['event_coord_x']) , axis = 1)
adjusted_frame['f_vax'] = adjusted_frame.apply(lambda row : venue_away[row['venue']]['x'](row['event_coord_x']) , axis = 1)
adjusted_frame['f_ax'] = adjusted_frame.apply(lambda row : venue_away['all']['x'](row['event_coord_x']) , axis = 1)
adjusted_frame['arg_x'] = adjusted_frame['f_vx'] - (adjusted_frame['f_vax'] - adjusted_frame['f_ax'])
adjusted_frame['arg_x'] = np.where(adjusted_frame['arg_x'] > 1, 1, adjusted_frame['arg_x'])
adjusted_frame['arg_x'] = np.where(adjusted_frame['arg_x'] < 0, 0, adjusted_frame['arg_x'])
adjusted_frame['adj_x'] = adjusted_frame['arg_x'].apply(lambda x: np.quantile(sorted_x, x, interpolation='linear'))

# %%
adjusted_frame['f_vy'] = adjusted_frame.apply(lambda row : venue_all[row['venue']]['y'](row['event_coord_y']) , axis = 1)
adjusted_frame['f_vay'] = adjusted_frame.apply(lambda row : venue_away[row['venue']]['y'](row['event_coord_y']) , axis = 1)
adjusted_frame['f_ay'] = adjusted_frame.apply(lambda row : venue_away['all']['y'](row['event_coord_y']) , axis = 1)
adjusted_frame['arg_y'] = adjusted_frame['f_vy'] - (adjusted_frame['f_vay'] - adjusted_frame['f_ay'])
adjusted_frame['arg_y'] = np.where(adjusted_frame['arg_y'] > 1, 1, adjusted_frame['arg_y'])
adjusted_frame['arg_y'] = np.where(adjusted_frame['arg_y'] < 0, 0, adjusted_frame['arg_y'])
adjusted_frame['adj_y'] = adjusted_frame['arg_y'].apply(lambda x: np.quantile(sorted_y, x, interpolation='linear'))

# %%
adjusted_frame[['event_coord_x','event_coord_y','adj_x','adj_y']].head()

# %% [markdown]
# Using the adjusted coordinates, re-calculate the angle of the shot and the distance of the shot. These are determined by using the line segment starting at the midpoint of the goal line and ending at the adjusted shot location. The goal line corresponds to the line $x = 89$, indicating that the midpoint of the goal line is at coordinates $(89, 0)$. The adjusted distance `adj_dist` is simply the length of this segment. The adjusted angle `adj_angle` is the angle between this segment and the ray from the midpoint of the goal line passing through center ice (coordinates $(0,0)$).

# %%
adjusted_frame['adj_dist'] = np.sqrt((shot_frame['adj_x']-89)**2 + shot_frame['adj_y']**2)
adjusted_frame['adj_angle'] = np.arctan2(shot_frame['adj_y'], 89 - shot_frame['adj_x']) * 180 / np.pi
adjusted_frame['adj_angle'].describe()

# %% [markdown]
# The temporary columns are no longer needed.

# %%
adjusted_frame.drop(['f_vx', 'f_vax', 'f_ax', 'arg_x', 'f_vy', 'f_vay', 'f_ay', 'arg_y'], axis=1, inplace=True)

# %% [markdown]
# Re-check the differences for Madison Square Garden.

# %%
adjusted_frame['adj_dist'].describe()
# Out:
# count    1.428324e+06
# mean     3.336882e+01
# std      2.080060e+01
# min      0.000000e+00
# 25%      1.746425e+01
# 50%      3.046309e+01
# 75%      4.596738e+01
# max      1.926344e+02
# Name: adj_dist, dtype: float64

# %%
adjusted_frame[adjusted_frame['venue']=='Madison Square Garden']['adj_dist'].describe()
# Out:
# count    49132.000000
# mean        29.740026
# std         20.758430
# min          0.000000
# 25%         14.212670
# 50%         24.698178
# 75%         41.629317
# max        189.401690
# Name: adj_dist, dtype: float64

# %%
adjusted_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1428324 entries, 0 to 1428367
# Data columns (total 41 columns):
#  #   Column              Non-Null Count    Dtype
# ---  ------              --------------    -----
#  0   game_id_livefeed    1428324 non-null  object
#  1   season              1428324 non-null  object
#  2   type                1428324 non-null  object
#  3   game_time           1428324 non-null  object
#  4   away_code           1428324 non-null  object
#  5   home_code           1428324 non-null  object
#  6   venue               1428324 non-null  object
#  7   period              1428324 non-null  int64
#  8   period_ord          1428324 non-null  object
#  9   period_type         1428324 non-null  object
#  10  time_elapsed        1428324 non-null  object
#  11  cum_time_elapsed    1428324 non-null  float64
#  12  event               1428324 non-null  object
#  13  event_team_code     1428324 non-null  object
#  14  event_team_is_home  1428324 non-null  bool
#  15  event_coord_x       1428324 non-null  float64
#  16  event_coord_y       1428324 non-null  float64
#  17  secondary_type      769688 non-null   object
#  18  is_rebound          1428324 non-null  bool
#  19  strength            1428324 non-null  object
#  20  time_remaining      1428324 non-null  object
#  21  seconds_remaining   1428324 non-null  float64
#  22  skaters_a           1428324 non-null  int64
#  23  skaters_h           1428324 non-null  int64
#  24  goalie_pulled_a     1428324 non-null  bool
#  25  goalie_pulled_h     1428324 non-null  bool
#  26  shot_dist           1066157 non-null  float64
#  27  event_zone          1428324 non-null  object
#  28  miss_type           1428324 non-null  object
#  29  shot_type           1428235 non-null  object
#  30  calc_dist           1428324 non-null  float64
#  31  dist_difference     1066157 non-null  float64
#  32  players_h           1428324 non-null  int64
#  33  players_a           1428324 non-null  int64
#  34  fwds_h              1428324 non-null  int64
#  35  fwds_a              1428324 non-null  int64
#  36  calc_angle          1428324 non-null  float64
#  37  adj_x               1428324 non-null  float64
#  38  adj_y               1428324 non-null  float64
#  39  adj_dist            1428324 non-null  float64
#  40  adj_angle           1428324 non-null  float64
# dtypes: bool(4), float64(12), int64(7), object(18)
# memory usage: 419.5+ MB

# %% [markdown]
# The majority of NHL games are 60 minutes long, with a sizable minority having an additional time for overtime. We would expect the median event time to be roughly 30 minutes into the game

# %%
adjusted_frame['cum_time_elapsed'].describe()
# Out:
# count    1.428324e+06
# mean     1.834033e+03
# std      1.061119e+03
# min      0.000000e+00
# 25%      9.260000e+02
# 50%      1.819000e+03
# 75%      2.728000e+03
# max      9.027000e+03
# Name: cum_time_elapsed, dtype: float64

# %%
adjusted_frame['period_type'].unique()
# Out:
# array(['REGULAR', 'OVERTIME'], dtype=object)

# %%
adjusted_frame[adjusted_frame['period_type']=='REGULAR']['cum_time_elapsed'].describe()
# Out:
# count    1.402454e+06
# mean     1.796395e+03
# std      1.031972e+03
# min      0.000000e+00
# 25%      9.090000e+02
# 50%      1.787000e+03
# 75%      2.678750e+03
# max      3.600000e+03
# Name: cum_time_elapsed, dtype: float64

# %% [markdown]
# Likewise, most NHL periods are 20 minutes long. Only regular season overtimes are shorter, at 5 minutes. We would expect the median time remaining in a period to be 10 minutes.

# %%
adjusted_frame['seconds_remaining'].describe()
# Out:
# count    1.428324e+06
# mean     5.898845e+02
# std      3.480634e+02
# min      0.000000e+00
# 25%      2.830000e+02
# 50%      5.930000e+02
# 75%      8.930000e+02
# max      1.200000e+03
# Name: seconds_remaining, dtype: float64

# %%
adjusted_frame[adjusted_frame['period_type']=='REGULAR']['seconds_remaining'].describe()
# Out:
# count    1.402454e+06
# mean     5.955452e+02
# std      3.463804e+02
# min      0.000000e+00
# 25%      2.960000e+02
# 50%      6.010000e+02
# 75%      8.960000e+02
# max      1.200000e+03
# Name: seconds_remaining, dtype: float64

# %% [markdown]
# Overtimes are sudden-death, where a single goal ends the game. Since overtimes will often not last the entire scheduled time, we would expect the median regular-season overtime event to take place with over 2:30 remaining and the median playoff overtime event to take place with over 10:00 remining.

# %%
adjusted_frame[(adjusted_frame['period_type']=='OVERTIME') & (adjusted_frame['type'] =='R')]['seconds_remaining'].describe()
# Out:
# count    20357.000000
# mean       154.351329
# std         85.067489
# min          0.000000
# 25%         82.000000
# 50%        162.000000
# 75%        228.000000
# max        298.000000
# Name: seconds_remaining, dtype: float64

# %%
adjusted_frame[(adjusted_frame['period_type']=='OVERTIME') & (adjusted_frame['type'] =='P')]['seconds_remaining'].describe()
# Out:
# count    5513.000000
# mean      758.071830
# std       319.737652
# min         0.000000
# 25%       529.000000
# 50%       826.000000
# 75%      1032.000000
# max      1195.000000
# Name: seconds_remaining, dtype: float64

# %% [markdown]
# The valid number of players on the ice should vary from 4 to 6.

# %%
adjusted_frame['players_a'].value_counts()
# Out:
# 6     1259169
# 5      154813
# 4       14212
# 7         108
# 2          10
# 1           4
# 8           3
# 11          2
# 3           2
# 9           1
# Name: players_a, dtype: int64

# %%
adjusted_frame['players_h'].value_counts()
# Out:
# 6    1272398
# 5     142606
# 4      13237
# 7         61
# 2          8
# 1          8
# 3          3
# 8          2
# 9          1
# Name: players_h, dtype: int64

# %%
adjusted_frame = adjusted_frame[(adjusted_frame['players_a'] >= 4) & (adjusted_frame['players_a'] <= 6)]
adjusted_frame = adjusted_frame[(adjusted_frame['players_h'] >= 4) & (adjusted_frame['players_h'] <= 6)]

# %%
adjusted_frame['players_a'].value_counts()
# Out:
# 6    1259100
# 5     154804
# 4      14211
# Name: players_a, dtype: int64

# %%
adjusted_frame['players_h'].value_counts()
# Out:
# 6    1272278
# 5     142601
# 4      13236
# Name: players_h, dtype: int64

# %% [markdown]
# The number of skaters should vary between 3 and 6, with the most common value being 5. The number of forwards is allowed to vary between 0 and 6, with 3 being the most common.

# %%
adjusted_frame['skaters_a'].value_counts()
# Out:
# 5    1243032
# 4     154127
# 6      16781
# 3      14175
# Name: skaters_a, dtype: int64

# %%
adjusted_frame['skaters_h'].value_counts()
# Out:
# 5    1256996
# 4     141938
# 6      15971
# 3      13210
# Name: skaters_h, dtype: int64

# %%
adjusted_frame['fwds_a'].value_counts()
# Out:
# 3    1167805
# 2     170566
# 4      78216
# 1       6254
# 5       5122
# 6        150
# 0          2
# Name: fwds_a, dtype: int64

# %%
adjusted_frame['fwds_h'].value_counts()
# Out:
# 3    1175177
# 2     156863
# 4      85656
# 1       5301
# 5       5007
# 6        109
# 0          2
# Name: fwds_h, dtype: int64

# %% [markdown]
# Determine the attacker and defender strength. This is traditionally referenced as being 'M-on-N', where M is the number of attackers (non-goaltenders on the ice) for the shooting team and N is the number of non-goaltenders for the defending team. Most play is 5-on-5, as both teams have 6 players is most situations and usually have a goaltender on the ice. At most one goaltender is allowed at any one time.

# %%
adjusted_frame['players_shooting'] = np.where(adjusted_frame['event_team_is_home']==True,
                                            adjusted_frame['players_h'],
                                            adjusted_frame['players_a'])
adjusted_frame['skaters_shooting'] = np.where(adjusted_frame['event_team_is_home']==True,
                                            adjusted_frame['skaters_h'],
                                            adjusted_frame['skaters_a'])
adjusted_frame['fwds_shooting'] = np.where(adjusted_frame['event_team_is_home']==True,
                                            adjusted_frame['fwds_h'],
                                            adjusted_frame['fwds_a'])

# %%
def attacker_state(home_shooting, skaters_h, skaters_a):
    if home_shooting:
        result = str(skaters_h) + '-on-' + str(skaters_a)
    else:
        result = str(skaters_a) + '-on-' + str(skaters_h)
    return result

# %%
adjusted_frame['attacker_state'] = adjusted_frame.apply(lambda row: attacker_state(row['event_team_is_home'], row['skaters_h'], row['skaters_a']), axis = 1 )

# %%
adjusted_frame['attacker_state'].value_counts()
# Out:
# 5-on-5    1116417
# 5-on-4     202220
# 4-on-5      28795
# 4-on-4      28525
# 6-on-5      23272
# 3-on-3       7867
# 5-on-3       7089
# 5-on-6       5676
# 4-on-3       4133
# 6-on-4       3269
# 4-on-6        423
# 3-on-4        175
# 3-on-5        142
# 6-on-3        110
# 3-on-6          2
# Name: attacker_state, dtype: int64

# %%
current_dir = Path.cwd()
relative_path = 'data/processed.pkl'
frame_path = current_dir.joinpath(relative_path)
adjusted_frame.to_pickle(str(frame_path))

# %%
current_dir = Path.cwd()
relative_path = 'data/processed.pkl'
frame_path = current_dir.joinpath(relative_path)
adjusted_frame = pd.read_pickle(str(frame_path))

# %% [markdown]
# The pickle is too large for Github, but compressing the file works.

# %%
current_dir = Path.cwd()
relative_path = 'data/compressed.pbz2'
frame_path = current_dir.joinpath(relative_path)
with bz2.BZ2File(str(frame_path), 'w') as f: 
    cPickle.dump(adjusted_frame, f)

# %%
decompressed = bz2.BZ2File(str(frame_path), 'rb')
decompressed = cPickle.load(decompressed)

# %%
decompressed.equals(adjusted_frame)
# Out:
# True
